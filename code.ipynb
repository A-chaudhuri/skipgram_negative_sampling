# %%
import io
import math
import gzip
import nltk
import time
import random
import pandas as pd
import numpy as np
import tensorflow as tf
import gensim.downloader as api
import tensorflow_datasets as tfds
nltk.download('stopwords')

from collections import Counter
from nltk.corpus import stopwords
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import skipgrams
from keras.preprocessing import text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#reading dataset
file= open("interview_ds.txt", "r")
wiki = file.read()
wiki=wiki[:50000]

# %% [markdown]
# ##Data pre-processing

# %%
import re
# Tokenization
words = re.findall(r'\b\w+\b', wiki)

# Convert to lowercase
words = [word.lower() for word in words]

# Build Vocabulary
vocabulary = set(words)
word_to_index = {word: i for i, word in enumerate(vocabulary)}
index_to_word = {i: word for i, word in enumerate(vocabulary)}

# Generate Word Pairs
window_size = 2
word_pairs = []
for i, word in enumerate(words):
    for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
        if i != j:
            context_word = words[j]
            word_pairs.append((word, context_word))

# Assign Labels
labeled_data = [(pair, 1) for pair in word_pairs]

# %%
# Print the pre-processed data
print("Pre-processed Word Pairs:")
for data in labeled_data:
    print(data)
# Out:
# Streaming output truncated to the last 5000 lines.
# (('just', 'him'), 1)
# (('just', 'when'), 1)
# (('just', 'she'), 1)
# (('when', 'him'), 1)
# (('when', 'just'), 1)
# (('when', 'she'), 1)
# (('when', 'thought'), 1)
# (('she', 'just'), 1)
# (('she', 'when'), 1)
# (('she', 'thought'), 1)
# (('she', 'she'), 1)
# (('thought', 'when'), 1)
# (('thought', 'she'), 1)
# (('thought', 'she'), 1)
# (('thought', 'would'), 1)
# (('she', 'she'), 1)
# (('she', 'thought'), 1)
# (('she', 'would'), 1)
# (('she', 'never'), 1)
# (('would', 'thought'), 1)
# (('would', 'she'), 1)
# (('would', 'never'), 1)
# (('would', 'find'), 1)
# (('never', 'she'), 1)
# (('never', 'would'), 1)
# (('never', 'find'), 1)
# (('never', 'true'), 1)
# (('find', 'would'), 1)
# (('find', 'never'), 1)
# (('find', 'true'), 1)
# (('find', 'he'), 1)
# (('true', 'never'), 1)
# (('true', 'find'), 1)
# (('true', 'he'), 1)
# (('true', 'popped'), 1)
# (('he', 'find'), 1)
# (('he', 'true'), 1)
# (('he', 'popped'), 1)
# (('he', 'out'), 1)
# (('popped', 'true'), 1)
# (('popped', 'he'), 1)
# (('popped', 'out'), 1)
# (('popped', 'from'), 1)
# (('out', 'he'), 1)
# (('out', 'popped'), 1)
# (('out', 'from'), 1)
# (('out', 'behind'), 1)
# (('from', 'popped'), 1)
# (('from', 'out'), 1)
# (('from', 'behind'), 1)
# (('from', 'the'), 1)
# (('behind', 'out'), 1)
# (('behind', 'from'), 1)
# (('behind', 'the'), 1)
# (('behind', 'tree'), 1)
# (('the', 'from'), 1)
# (('the', 'behind'), 1)
# (('the', 'tree'), 1)
# (('the', 'wagging'), 1)
# (('tree', 'behind'), 1)
# (('tree', 'the'), 1)
# (('tree', 'wagging'), 1)
# (('tree', 'his'), 1)
# (('wagging', 'the'), 1)
# (('wagging', 'tree'), 1)
# (('wagging', 'his'), 1)
# (('wagging', 'tail'), 1)
# (('his', 'tree'), 1)
# (('his', 'wagging'), 1)
# (('his', 'tail'), 1)
# (('his', 'lily'), 1)
# (('tail', 'wagging'), 1)
# (('tail', 'his'), 1)
# (('tail', 'lily'), 1)
# (('tail', 'was'), 1)
# (('lily', 'his'), 1)
# (('lily', 'tail'), 1)
# (('lily', 'was'), 1)
# (('lily', 'so'), 1)
# (('was', 'tail'), 1)
# (('was', 'lily'), 1)
# (('was', 'so'), 1)
# (('was', 'happy'), 1)
# (('so', 'lily'), 1)
# (('so', 'was'), 1)
# (('so', 'happy'), 1)
# (('so', 'to'), 1)
# (('happy', 'was'), 1)
# (('happy', 'so'), 1)
# (('happy', 'to'), 1)
# (('happy', 'see'), 1)
# (('to', 'so'), 1)
# (('to', 'happy'), 1)
# (('to', 'see'), 1)
# (('to', 'him'), 1)
# (('see', 'happy'), 1)
# (('see', 'to'), 1)
# (('see', 'him'), 1)
# (('see', 'and'), 1)
# (('him', 'to'), 1)
# (('him', 'see'), 1)
# (('him', 'and'), 1)
# (('him', 'gave'), 1)
# (('and', 'see'), 1)
# (('and', 'him'), 1)
# (('and', 'gave'), 1)
# (('and', 'him'), 1)
# (('gave', 'him'), 1)
# (('gave', 'and'), 1)
# (('gave', 'him'), 1)
# (('gave', 'a'), 1)
# (('him', 'and'), 1)
# (('him', 'gave'), 1)
# (('him', 'a'), 1)
# (('him', 'big'), 1)
# (('a', 'gave'), 1)
# (('a', 'him'), 1)
# (('a', 'big'), 1)
# (('a', 'hug'), 1)
# (('big', 'him'), 1)
# (('big', 'a'), 1)
# (('big', 'hug'), 1)
# (('big', 'from'), 1)
# (('hug', 'a'), 1)
# (('hug', 'big'), 1)
# (('hug', 'from'), 1)
# (('hug', 'then'), 1)
# (('from', 'big'), 1)
# (('from', 'hug'), 1)
# (('from', 'then'), 1)
# (('from', 'on'), 1)
# (('then', 'hug'), 1)
# (('then', 'from'), 1)
# (('then', 'on'), 1)
# (('then', 'they'), 1)
# (('on', 'from'), 1)
# (('on', 'then'), 1)
# (('on', 'they'), 1)
# (('on', 'never'), 1)
# (('they', 'then'), 1)
# (('they', 'on'), 1)
# (('they', 'never'), 1)
# (('they', 'played'), 1)
# (('never', 'on'), 1)
# (('never', 'they'), 1)
# (('never', 'played'), 1)
# (('never', 'hide'), 1)
# (('played', 'they'), 1)
# (('played', 'never'), 1)
# (('played', 'hide'), 1)
# (('played', 'and'), 1)
# (('hide', 'never'), 1)
# (('hide', 'played'), 1)
# (('hide', 'and'), 1)
# (('hide', 'seek'), 1)
# (('and', 'played'), 1)
# (('and', 'hide'), 1)
# (('and', 'seek'), 1)
# (('and', 'again'), 1)
# (('seek', 'hide'), 1)
# (('seek', 'and'), 1)
# (('seek', 'again'), 1)
# (('seek', 'without'), 1)
# (('again', 'and'), 1)
# (('again', 'seek'), 1)
# (('again', 'without'), 1)
# (('again', 'calling'), 1)
# (('without', 'seek'), 1)
# (('without', 'again'), 1)
# (('without', 'calling'), 1)
# (('without', 'out'), 1)
# (('calling', 'again'), 1)
# (('calling', 'without'), 1)
# (('calling', 'out'), 1)
# (('calling', 'for'), 1)
# (('out', 'without'), 1)
# (('out', 'calling'), 1)
# (('out', 'for'), 1)
# (('out', 'each'), 1)
# (('for', 'calling'), 1)
# (('for', 'out'), 1)
# (('for', 'each'), 1)
# (('for', 'other'), 1)
# (('each', 'out'), 1)
# (('each', 'for'), 1)
# (('each', 'other'), 1)
# (('each', 'first'), 1)
# (('other', 'for'), 1)
# (('other', 'each'), 1)
# (('other', 'first'), 1)
# (('other', 'once'), 1)
# (('first', 'each'), 1)
# (('first', 'other'), 1)
# (('first', 'once'), 1)
# (('first', 'upon'), 1)
# (('once', 'other'), 1)
# (('once', 'first'), 1)
# (('once', 'upon'), 1)
# (('once', 'a'), 1)
# (('upon', 'first'), 1)
# (('upon', 'once'), 1)
# (('upon', 'a'), 1)
# (('upon', 'time'), 1)
# (('a', 'once'), 1)
# (('a', 'upon'), 1)
# (('a', 'time'), 1)
# (('a', 'there'), 1)
# (('time', 'upon'), 1)
# (('time', 'a'), 1)
# (('time', 'there'), 1)
# (('time', 'was'), 1)
# (('there', 'a'), 1)
# (('there', 'time'), 1)
# (('there', 'was'), 1)
# (('there', 'a'), 1)
# (('was', 'time'), 1)
# (('was', 'there'), 1)
# (('was', 'a'), 1)
# (('was', 'little'), 1)
# (('a', 'there'), 1)
# (('a', 'was'), 1)
# (('a', 'little'), 1)
# (('a', 'girl'), 1)
# (('little', 'was'), 1)
# (('little', 'a'), 1)
# (('little', 'girl'), 1)
# (('little', 'named'), 1)
# (('girl', 'a'), 1)
# (('girl', 'little'), 1)
# (('girl', 'named'), 1)
# (('girl', 'lily'), 1)
# (('named', 'little'), 1)
# (('named', 'girl'), 1)
# (('named', 'lily'), 1)
# (('named', 'she'), 1)
# (('lily', 'girl'), 1)
# (('lily', 'named'), 1)
# (('lily', 'she'), 1)
# (('lily', 'loved'), 1)
# (('she', 'named'), 1)
# (('she', 'lily'), 1)
# (('she', 'loved'), 1)
# (('she', 'to'), 1)
# (('loved', 'lily'), 1)
# (('loved', 'she'), 1)
# (('loved', 'to'), 1)
# (('loved', 'draw'), 1)
# (('to', 'she'), 1)
# (('to', 'loved'), 1)
# (('to', 'draw'), 1)
# (('to', 'and'), 1)
# (('draw', 'loved'), 1)
# (('draw', 'to'), 1)
# (('draw', 'and'), 1)
# (('draw', 'create'), 1)
# (('and', 'to'), 1)
# (('and', 'draw'), 1)
# (('and', 'create'), 1)
# (('and', 'beautiful'), 1)
# (('create', 'draw'), 1)
# (('create', 'and'), 1)
# (('create', 'beautiful'), 1)
# (('create', 'pictures'), 1)
# (('beautiful', 'and'), 1)
# (('beautiful', 'create'), 1)
# (('beautiful', 'pictures'), 1)
# (('beautiful', 'with'), 1)
# (('pictures', 'create'), 1)
# (('pictures', 'beautiful'), 1)
# (('pictures', 'with'), 1)
# (('pictures', 'her'), 1)
# (('with', 'beautiful'), 1)
# (('with', 'pictures'), 1)
# (('with', 'her'), 1)
# (('with', 'crayons'), 1)
# (('her', 'pictures'), 1)
# (('her', 'with'), 1)
# (('her', 'crayons'), 1)
# (('her', 'one'), 1)
# (('crayons', 'with'), 1)
# (('crayons', 'her'), 1)
# (('crayons', 'one'), 1)
# (('crayons', 'day'), 1)
# (('one', 'her'), 1)
# (('one', 'crayons'), 1)
# (('one', 'day'), 1)
# (('one', 'she'), 1)
# (('day', 'crayons'), 1)
# (('day', 'one'), 1)
# (('day', 'she'), 1)
# (('day', 'drew'), 1)
# (('she', 'one'), 1)
# (('she', 'day'), 1)
# (('she', 'drew'), 1)
# (('she', 'a'), 1)
# (('drew', 'day'), 1)
# (('drew', 'she'), 1)
# (('drew', 'a'), 1)
# (('drew', 'picture'), 1)
# (('a', 'she'), 1)
# (('a', 'drew'), 1)
# (('a', 'picture'), 1)
# (('a', 'of'), 1)
# (('picture', 'drew'), 1)
# (('picture', 'a'), 1)
# (('picture', 'of'), 1)
# (('picture', 'a'), 1)
# (('of', 'a'), 1)
# (('of', 'picture'), 1)
# (('of', 'a'), 1)
# (('of', 'big'), 1)
# (('a', 'picture'), 1)
# (('a', 'of'), 1)
# (('a', 'big'), 1)
# (('a', 'yellow'), 1)
# (('big', 'of'), 1)
# (('big', 'a'), 1)
# (('big', 'yellow'), 1)
# (('big', 'sun'), 1)
# (('yellow', 'a'), 1)
# (('yellow', 'big'), 1)
# (('yellow', 'sun'), 1)
# (('yellow', 'and'), 1)
# (('sun', 'big'), 1)
# (('sun', 'yellow'), 1)
# (('sun', 'and'), 1)
# (('sun', 'a'), 1)
# (('and', 'yellow'), 1)
# (('and', 'sun'), 1)
# (('and', 'a'), 1)
# (('and', 'green'), 1)
# (('a', 'sun'), 1)
# (('a', 'and'), 1)
# (('a', 'green'), 1)
# (('a', 'grassy'), 1)
# (('green', 'and'), 1)
# (('green', 'a'), 1)
# (('green', 'grassy'), 1)
# (('green', 'field'), 1)
# (('grassy', 'a'), 1)
# (('grassy', 'green'), 1)
# (('grassy', 'field'), 1)
# (('grassy', 'her'), 1)
# (('field', 'green'), 1)
# (('field', 'grassy'), 1)
# (('field', 'her'), 1)
# (('field', 'mom'), 1)
# (('her', 'grassy'), 1)
# (('her', 'field'), 1)
# (('her', 'mom'), 1)
# (('her', 'saw'), 1)
# (('mom', 'field'), 1)
# (('mom', 'her'), 1)
# (('mom', 'saw'), 1)
# (('mom', 'the'), 1)
# (('saw', 'her'), 1)
# (('saw', 'mom'), 1)
# (('saw', 'the'), 1)
# (('saw', 'picture'), 1)
# (('the', 'mom'), 1)
# (('the', 'saw'), 1)
# (('the', 'picture'), 1)
# (('the', 'and'), 1)
# (('picture', 'saw'), 1)
# (('picture', 'the'), 1)
# (('picture', 'and'), 1)
# (('picture', 'said'), 1)
# (('and', 'the'), 1)
# (('and', 'picture'), 1)
# (('and', 'said'), 1)
# (('and', 'wow'), 1)
# (('said', 'picture'), 1)
# (('said', 'and'), 1)
# (('said', 'wow'), 1)
# (('said', 'lily'), 1)
# (('wow', 'and'), 1)
# (('wow', 'said'), 1)
# (('wow', 'lily'), 1)
# (('wow', 'you'), 1)
# (('lily', 'said'), 1)
# (('lily', 'wow'), 1)
# (('lily', 'you'), 1)
# (('lily', 'created'), 1)
# (('you', 'wow'), 1)
# (('you', 'lily'), 1)
# (('you', 'created'), 1)
# (('you', 'a'), 1)
# (('created', 'lily'), 1)
# (('created', 'you'), 1)
# (('created', 'a'), 1)
# (('created', 'beautiful'), 1)
# (('a', 'you'), 1)
# (('a', 'created'), 1)
# (('a', 'beautiful'), 1)
# (('a', 'picture'), 1)
# (('beautiful', 'created'), 1)
# (('beautiful', 'a'), 1)
# (('beautiful', 'picture'), 1)
# (('beautiful', 'later'), 1)
# (('picture', 'a'), 1)
# (('picture', 'beautiful'), 1)
# (('picture', 'later'), 1)
# (('picture', 'that'), 1)
# (('later', 'beautiful'), 1)
# (('later', 'picture'), 1)
# (('later', 'that'), 1)
# (('later', 'night'), 1)
# (('that', 'picture'), 1)
# (('that', 'later'), 1)
# (('that', 'night'), 1)
# (('that', 'lily'), 1)
# (('night', 'later'), 1)
# (('night', 'that'), 1)
# (('night', 'lily'), 1)
# (('night', 'went'), 1)
# (('lily', 'that'), 1)
# (('lily', 'night'), 1)
# (('lily', 'went'), 1)
# (('lily', 'to'), 1)
# (('went', 'night'), 1)
# (('went', 'lily'), 1)
# (('went', 'to'), 1)
# (('went', 'bed'), 1)
# (('to', 'lily'), 1)
# (('to', 'went'), 1)
# (('to', 'bed'), 1)
# (('to', 'feeling'), 1)
# (('bed', 'went'), 1)
# (('bed', 'to'), 1)
# (('bed', 'feeling'), 1)
# (('bed', 'very'), 1)
# (('feeling', 'to'), 1)
# (('feeling', 'bed'), 1)
# (('feeling', 'very'), 1)
# (('feeling', 'comfortable'), 1)
# (('very', 'bed'), 1)
# (('very', 'feeling'), 1)
# (('very', 'comfortable'), 1)
# (('very', 'in'), 1)
# (('comfortable', 'feeling'), 1)
# (('comfortable', 'very'), 1)
# (('comfortable', 'in'), 1)
# (('comfortable', 'her'), 1)
# (('in', 'very'), 1)
# (('in', 'comfortable'), 1)
# (('in', 'her'), 1)
# (('in', 'cozy'), 1)
# (('her', 'comfortable'), 1)
# (('her', 'in'), 1)
# (('her', 'cozy'), 1)
# (('her', 'pajamas'), 1)
# (('cozy', 'in'), 1)
# (('cozy', 'her'), 1)
# (('cozy', 'pajamas'), 1)
# (('cozy', 'but'), 1)
# (('pajamas', 'her'), 1)
# (('pajamas', 'cozy'), 1)
# (('pajamas', 'but'), 1)
# (('pajamas', 'in'), 1)
# (('but', 'cozy'), 1)
# (('but', 'pajamas'), 1)
# (('but', 'in'), 1)
# (('but', 'the'), 1)
# (('in', 'pajamas'), 1)
# (('in', 'but'), 1)
# (('in', 'the'), 1)
# (('in', 'middle'), 1)
# (('the', 'but'), 1)
# (('the', 'in'), 1)
# (('the', 'middle'), 1)
# (('the', 'of'), 1)
# (('middle', 'in'), 1)
# (('middle', 'the'), 1)
# (('middle', 'of'), 1)
# (('middle', 'the'), 1)
# (('of', 'the'), 1)
# (('of', 'middle'), 1)
# (('of', 'the'), 1)
# (('of', 'night'), 1)
# (('the', 'middle'), 1)
# (('the', 'of'), 1)
# (('the', 'night'), 1)
# (('the', 'she'), 1)
# (('night', 'of'), 1)
# (('night', 'the'), 1)
# (('night', 'she'), 1)
# (('night', 'woke'), 1)
# (('she', 'the'), 1)
# (('she', 'night'), 1)
# (('she', 'woke'), 1)
# (('she', 'up'), 1)
# (('woke', 'night'), 1)
# (('woke', 'she'), 1)
# (('woke', 'up'), 1)
# (('woke', 'from'), 1)
# (('up', 'she'), 1)
# (('up', 'woke'), 1)
# (('up', 'from'), 1)
# (('up', 'a'), 1)
# (('from', 'woke'), 1)
# (('from', 'up'), 1)
# (('from', 'a'), 1)
# (('from', 'bad'), 1)
# (('a', 'up'), 1)
# (('a', 'from'), 1)
# (('a', 'bad'), 1)
# (('a', 'dream'), 1)
# (('bad', 'from'), 1)
# (('bad', 'a'), 1)
# (('bad', 'dream'), 1)
# (('bad', 'she'), 1)
# (('dream', 'a'), 1)
# (('dream', 'bad'), 1)
# (('dream', 'she'), 1)
# (('dream', 'called'), 1)
# (('she', 'bad'), 1)
# (('she', 'dream'), 1)
# (('she', 'called'), 1)
# (('she', 'out'), 1)
# (('called', 'dream'), 1)
# (('called', 'she'), 1)
# (('called', 'out'), 1)
# (('called', 'to'), 1)
# (('out', 'she'), 1)
# (('out', 'called'), 1)
# (('out', 'to'), 1)
# (('out', 'her'), 1)
# (('to', 'called'), 1)
# (('to', 'out'), 1)
# (('to', 'her'), 1)
# (('to', 'mom'), 1)
# (('her', 'out'), 1)
# (('her', 'to'), 1)
# (('her', 'mom'), 1)
# (('her', 'mommy'), 1)
# (('mom', 'to'), 1)
# (('mom', 'her'), 1)
# (('mom', 'mommy'), 1)
# (('mom', 'can'), 1)
# (('mommy', 'her'), 1)
# (('mommy', 'mom'), 1)
# (('mommy', 'can'), 1)
# (('mommy', 'you'), 1)
# (('can', 'mom'), 1)
# (('can', 'mommy'), 1)
# (('can', 'you'), 1)
# (('can', 'come'), 1)
# (('you', 'mommy'), 1)
# (('you', 'can'), 1)
# (('you', 'come'), 1)
# (('you', 'in'), 1)
# (('come', 'can'), 1)
# (('come', 'you'), 1)
# (('come', 'in'), 1)
# (('come', 'and'), 1)
# (('in', 'you'), 1)
# (('in', 'come'), 1)
# (('in', 'and'), 1)
# (('in', 'make'), 1)
# (('and', 'come'), 1)
# (('and', 'in'), 1)
# (('and', 'make'), 1)
# (('and', 'me'), 1)
# (('make', 'in'), 1)
# (('make', 'and'), 1)
# (('make', 'me'), 1)
# (('make', 'feel'), 1)
# (('me', 'and'), 1)
# (('me', 'make'), 1)
# (('me', 'feel'), 1)
# (('me', 'better'), 1)
# (('feel', 'make'), 1)
# (('feel', 'me'), 1)
# (('feel', 'better'), 1)
# (('feel', 'her'), 1)
# (('better', 'me'), 1)
# (('better', 'feel'), 1)
# (('better', 'her'), 1)
# (('better', 'mom'), 1)
# (('her', 'feel'), 1)
# (('her', 'better'), 1)
# (('her', 'mom'), 1)
# (('her', 'came'), 1)
# (('mom', 'better'), 1)
# (('mom', 'her'), 1)
# (('mom', 'came'), 1)
# (('mom', 'in'), 1)
# (('came', 'her'), 1)
# (('came', 'mom'), 1)
# (('came', 'in'), 1)
# (('came', 'and'), 1)
# (('in', 'mom'), 1)
# (('in', 'came'), 1)
# (('in', 'and'), 1)
# (('in', 'hugged'), 1)
# (('and', 'came'), 1)
# (('and', 'in'), 1)
# (('and', 'hugged'), 1)
# (('and', 'her'), 1)
# (('hugged', 'in'), 1)
# (('hugged', 'and'), 1)
# (('hugged', 'her'), 1)
# (('hugged', 'saying'), 1)
# (('her', 'and'), 1)
# (('her', 'hugged'), 1)
# (('her', 'saying'), 1)
# (('her', 'don'), 1)
# (('saying', 'hugged'), 1)
# (('saying', 'her'), 1)
# (('saying', 'don'), 1)
# (('saying', 't'), 1)
# (('don', 'her'), 1)
# (('don', 'saying'), 1)
# (('don', 't'), 1)
# (('don', 'worry'), 1)
# (('t', 'saying'), 1)
# (('t', 'don'), 1)
# (('t', 'worry'), 1)
# (('t', 'lily'), 1)
# (('worry', 'don'), 1)
# (('worry', 't'), 1)
# (('worry', 'lily'), 1)
# (('worry', 'everything'), 1)
# (('lily', 't'), 1)
# (('lily', 'worry'), 1)
# (('lily', 'everything'), 1)
# (('lily', 'is'), 1)
# (('everything', 'worry'), 1)
# (('everything', 'lily'), 1)
# (('everything', 'is'), 1)
# (('everything', 'okay'), 1)
# (('is', 'lily'), 1)
# (('is', 'everything'), 1)
# (('is', 'okay'), 1)
# (('is', 'you'), 1)
# (('okay', 'everything'), 1)
# (('okay', 'is'), 1)
# (('okay', 'you'), 1)
# (('okay', 'are'), 1)
# (('you', 'is'), 1)
# (('you', 'okay'), 1)
# (('you', 'are'), 1)
# (('you', 'safe'), 1)
# (('are', 'okay'), 1)
# (('are', 'you'), 1)
# (('are', 'safe'), 1)
# (('are', 'and'), 1)
# (('safe', 'you'), 1)
# (('safe', 'are'), 1)
# (('safe', 'and'), 1)
# (('safe', 'loved'), 1)
# (('and', 'are'), 1)
# (('and', 'safe'), 1)
# (('and', 'loved'), 1)
# (('and', 'lily'), 1)
# (('loved', 'safe'), 1)
# (('loved', 'and'), 1)
# (('loved', 'lily'), 1)
# (('loved', 'felt'), 1)
# (('lily', 'and'), 1)
# (('lily', 'loved'), 1)
# (('lily', 'felt'), 1)
# (('lily', 'much'), 1)
# (('felt', 'loved'), 1)
# (('felt', 'lily'), 1)
# (('felt', 'much'), 1)
# (('felt', 'better'), 1)
# (('much', 'lily'), 1)
# (('much', 'felt'), 1)
# (('much', 'better'), 1)
# (('much', 'and'), 1)
# (('better', 'felt'), 1)
# (('better', 'much'), 1)
# (('better', 'and'), 1)
# (('better', 'fell'), 1)
# (('and', 'much'), 1)
# (('and', 'better'), 1)
# (('and', 'fell'), 1)
# (('and', 'back'), 1)
# (('fell', 'better'), 1)
# (('fell', 'and'), 1)
# (('fell', 'back'), 1)
# (('fell', 'asleep'), 1)
# (('back', 'and'), 1)
# (('back', 'fell'), 1)
# (('back', 'asleep'), 1)
# (('back', 'dreaming'), 1)
# (('asleep', 'fell'), 1)
# (('asleep', 'back'), 1)
# (('asleep', 'dreaming'), 1)
# (('asleep', 'of'), 1)
# (('dreaming', 'back'), 1)
# (('dreaming', 'asleep'), 1)
# (('dreaming', 'of'), 1)
# (('dreaming', 'more'), 1)
# (('of', 'asleep'), 1)
# (('of', 'dreaming'), 1)
# (('of', 'more'), 1)
# (('of', 'beautiful'), 1)
# (('more', 'dreaming'), 1)
# (('more', 'of'), 1)
# (('more', 'beautiful'), 1)
# (('more', 'pictures'), 1)
# (('beautiful', 'of'), 1)
# (('beautiful', 'more'), 1)
# (('beautiful', 'pictures'), 1)
# (('beautiful', 'she'), 1)
# (('pictures', 'more'), 1)
# (('pictures', 'beautiful'), 1)
# (('pictures', 'she'), 1)
# (('pictures', 'could'), 1)
# (('she', 'beautiful'), 1)
# (('she', 'pictures'), 1)
# (('she', 'could'), 1)
# (('she', 'create'), 1)
# (('could', 'pictures'), 1)
# (('could', 'she'), 1)
# (('could', 'create'), 1)
# (('could', 'the'), 1)
# (('create', 'she'), 1)
# (('create', 'could'), 1)
# (('create', 'the'), 1)
# (('create', 'next'), 1)
# (('the', 'could'), 1)
# (('the', 'create'), 1)
# (('the', 'next'), 1)
# (('the', 'day'), 1)
# (('next', 'create'), 1)
# (('next', 'the'), 1)
# (('next', 'day'), 1)
# (('next', 'once'), 1)
# (('day', 'the'), 1)
# (('day', 'next'), 1)
# (('day', 'once'), 1)
# (('day', 'upon'), 1)
# (('once', 'next'), 1)
# (('once', 'day'), 1)
# (('once', 'upon'), 1)
# (('once', 'a'), 1)
# (('upon', 'day'), 1)
# (('upon', 'once'), 1)
# (('upon', 'a'), 1)
# (('upon', 'time'), 1)
# (('a', 'once'), 1)
# (('a', 'upon'), 1)
# (('a', 'time'), 1)
# (('a', 'there'), 1)
# (('time', 'upon'), 1)
# (('time', 'a'), 1)
# (('time', 'there'), 1)
# (('time', 'was'), 1)
# (('there', 'a'), 1)
# (('there', 'time'), 1)
# (('there', 'was'), 1)
# (('there', 'an'), 1)
# (('was', 'time'), 1)
# (('was', 'there'), 1)
# (('was', 'an'), 1)
# (('was', 'incredible'), 1)
# (('an', 'there'), 1)
# (('an', 'was'), 1)
# (('an', 'incredible'), 1)
# (('an', 'little'), 1)
# (('incredible', 'was'), 1)
# (('incredible', 'an'), 1)
# (('incredible', 'little'), 1)
# (('incredible', 'girl'), 1)
# (('little', 'an'), 1)
# (('little', 'incredible'), 1)
# (('little', 'girl'), 1)
# (('little', 'her'), 1)
# (('girl', 'incredible'), 1)
# (('girl', 'little'), 1)
# (('girl', 'her'), 1)
# (('girl', 'name'), 1)
# (('her', 'little'), 1)
# (('her', 'girl'), 1)
# (('her', 'name'), 1)
# (('her', 'was'), 1)
# (('name', 'girl'), 1)
# (('name', 'her'), 1)
# (('name', 'was'), 1)
# (('name', 'jenny'), 1)
# (('was', 'her'), 1)
# (('was', 'name'), 1)
# (('was', 'jenny'), 1)
# (('was', 'on'), 1)
# (('jenny', 'name'), 1)
# (('jenny', 'was'), 1)
# (('jenny', 'on'), 1)
# (('jenny', 'one'), 1)
# (('on', 'was'), 1)
# (('on', 'jenny'), 1)
# (('on', 'one'), 1)
# (('on', 'sunny'), 1)
# (('one', 'jenny'), 1)
# (('one', 'on'), 1)
# (('one', 'sunny'), 1)
# (('one', 'day'), 1)
# (('sunny', 'on'), 1)
# (('sunny', 'one'), 1)
# (('sunny', 'day'), 1)
# (('sunny', 'jenny'), 1)
# (('day', 'one'), 1)
# (('day', 'sunny'), 1)
# (('day', 'jenny'), 1)
# (('day', 's'), 1)
# (('jenny', 'sunny'), 1)
# (('jenny', 'day'), 1)
# (('jenny', 's'), 1)
# (('jenny', 'parents'), 1)
# (('s', 'day'), 1)
# (('s', 'jenny'), 1)
# (('s', 'parents'), 1)
# (('s', 'took'), 1)
# (('parents', 'jenny'), 1)
# (('parents', 's'), 1)
# (('parents', 'took'), 1)
# (('parents', 'her'), 1)
# (('took', 's'), 1)
# (('took', 'parents'), 1)
# (('took', 'her'), 1)
# (('took', 'to'), 1)
# (('her', 'parents'), 1)
# (('her', 'took'), 1)
# (('her', 'to'), 1)
# (('her', 'the'), 1)
# (('to', 'took'), 1)
# (('to', 'her'), 1)
# (('to', 'the'), 1)
# (('to', 'beach'), 1)
# (('the', 'her'), 1)
# (('the', 'to'), 1)
# (('the', 'beach'), 1)
# (('the', 'jenny'), 1)
# (('beach', 'to'), 1)
# (('beach', 'the'), 1)
# (('beach', 'jenny'), 1)
# (('beach', 's'), 1)
# (('jenny', 'the'), 1)
# (('jenny', 'beach'), 1)
# (('jenny', 's'), 1)
# (('jenny', 'mom'), 1)
# (('s', 'beach'), 1)
# (('s', 'jenny'), 1)
# (('s', 'mom'), 1)
# (('s', 'carried'), 1)
# (('mom', 'jenny'), 1)
# (('mom', 's'), 1)
# (('mom', 'carried'), 1)
# (('mom', 'a'), 1)
# (('carried', 's'), 1)
# (('carried', 'mom'), 1)
# (('carried', 'a'), 1)
# (('carried', 'big'), 1)
# (('a', 'mom'), 1)
# (('a', 'carried'), 1)
# (('a', 'big'), 1)
# (('a', 'glass'), 1)
# (('big', 'carried'), 1)
# (('big', 'a'), 1)
# (('big', 'glass'), 1)
# (('big', 'and'), 1)
# (('glass', 'a'), 1)
# (('glass', 'big'), 1)
# (('glass', 'and'), 1)
# (('glass', 'filled'), 1)
# (('and', 'big'), 1)
# (('and', 'glass'), 1)
# (('and', 'filled'), 1)
# (('and', 'it'), 1)
# (('filled', 'glass'), 1)
# (('filled', 'and'), 1)
# (('filled', 'it'), 1)
# (('filled', 'with'), 1)
# (('it', 'and'), 1)
# (('it', 'filled'), 1)
# (('it', 'with'), 1)
# (('it', 'sand'), 1)
# (('with', 'filled'), 1)
# (('with', 'it'), 1)
# (('with', 'sand'), 1)
# (('with', 'she'), 1)
# (('sand', 'it'), 1)
# (('sand', 'with'), 1)
# (('sand', 'she'), 1)
# (('sand', 'said'), 1)
# (('she', 'with'), 1)
# (('she', 'sand'), 1)
# (('she', 'said'), 1)
# (('she', 'look'), 1)
# (('said', 'sand'), 1)
# (('said', 'she'), 1)
# (('said', 'look'), 1)
# (('said', 'i'), 1)
# (('look', 'she'), 1)
# (('look', 'said'), 1)
# (('look', 'i'), 1)
# (('look', 'm'), 1)
# (('i', 'said'), 1)
# (('i', 'look'), 1)
# (('i', 'm'), 1)
# (('i', 'going'), 1)
# (('m', 'look'), 1)
# (('m', 'i'), 1)
# (('m', 'going'), 1)
# (('m', 'to'), 1)
# (('going', 'i'), 1)
# (('going', 'm'), 1)
# (('going', 'to'), 1)
# (('going', 'support'), 1)
# (('to', 'm'), 1)
# (('to', 'going'), 1)
# (('to', 'support'), 1)
# (('to', 'this'), 1)
# (('support', 'going'), 1)
# (('support', 'to'), 1)
# (('support', 'this'), 1)
# (('support', 'glass'), 1)
# (('this', 'to'), 1)
# (('this', 'support'), 1)
# (('this', 'glass'), 1)
# (('this', 'on'), 1)
# (('glass', 'support'), 1)
# (('glass', 'this'), 1)
# (('glass', 'on'), 1)
# (('glass', 'the'), 1)
# (('on', 'this'), 1)
# (('on', 'glass'), 1)
# (('on', 'the'), 1)
# (('on', 'sand'), 1)
# (('the', 'glass'), 1)
# (('the', 'on'), 1)
# (('the', 'sand'), 1)
# (('the', 'so'), 1)
# (('sand', 'on'), 1)
# (('sand', 'the'), 1)
# (('sand', 'so'), 1)
# (('sand', 'it'), 1)
# (('so', 'the'), 1)
# (('so', 'sand'), 1)
# (('so', 'it'), 1)
# (('so', 'will'), 1)
# (('it', 'sand'), 1)
# (('it', 'so'), 1)
# (('it', 'will'), 1)
# (('it', 'stay'), 1)
# (('will', 'so'), 1)
# (('will', 'it'), 1)
# (('will', 'stay'), 1)
# (('will', 'up'), 1)
# (('stay', 'it'), 1)
# (('stay', 'will'), 1)
# (('stay', 'up'), 1)
# (('stay', 'jenny'), 1)
# (('up', 'will'), 1)
# (('up', 'stay'), 1)
# (('up', 'jenny'), 1)
# (('up', 'was'), 1)
# (('jenny', 'stay'), 1)
# (('jenny', 'up'), 1)
# (('jenny', 'was'), 1)
# (('jenny', 'very'), 1)
# (('was', 'up'), 1)
# (('was', 'jenny'), 1)
# (('was', 'very'), 1)
# (('was', 'surprised'), 1)
# (('very', 'jenny'), 1)
# (('very', 'was'), 1)
# (('very', 'surprised'), 1)
# (('very', 'she'), 1)
# (('surprised', 'was'), 1)
# (('surprised', 'very'), 1)
# (('surprised', 'she'), 1)
# (('surprised', 'said'), 1)
# (('she', 'very'), 1)
# (('she', 'surprised'), 1)
# (('she', 'said'), 1)
# (('she', 'that'), 1)
# (('said', 'surprised'), 1)
# (('said', 'she'), 1)
# (('said', 'that'), 1)
# (('said', 's'), 1)
# (('that', 'she'), 1)
# (('that', 'said'), 1)
# (('that', 's'), 1)
# (('that', 'incredible'), 1)
# (('s', 'said'), 1)
# (('s', 'that'), 1)
# (('s', 'incredible'), 1)
# (('s', 'can'), 1)
# (('incredible', 'that'), 1)
# (('incredible', 's'), 1)
# (('incredible', 'can'), 1)
# (('incredible', 'i'), 1)
# (('can', 's'), 1)
# (('can', 'incredible'), 1)
# (('can', 'i'), 1)
# (('can', 'help'), 1)
# (('i', 'incredible'), 1)
# (('i', 'can'), 1)
# (('i', 'help'), 1)
# (('i', 'you'), 1)
# (('help', 'can'), 1)
# (('help', 'i'), 1)
# (('help', 'you'), 1)
# (('help', 'jenny'), 1)
# (('you', 'i'), 1)
# (('you', 'help'), 1)
# (('you', 'jenny'), 1)
# (('you', 'and'), 1)
# (('jenny', 'help'), 1)
# (('jenny', 'you'), 1)
# (('jenny', 'and'), 1)
# (('jenny', 'her'), 1)
# (('and', 'you'), 1)
# (('and', 'jenny'), 1)
# (('and', 'her'), 1)
# (('and', 'mom'), 1)
# (('her', 'jenny'), 1)
# (('her', 'and'), 1)
# (('her', 'mom'), 1)
# (('her', 'worked'), 1)
# (('mom', 'and'), 1)
# (('mom', 'her'), 1)
# (('mom', 'worked'), 1)
# (('mom', 'together'), 1)
# (('worked', 'her'), 1)
# (('worked', 'mom'), 1)
# (('worked', 'together'), 1)
# (('worked', 'to'), 1)
# (('together', 'mom'), 1)
# (('together', 'worked'), 1)
# (('together', 'to'), 1)
# (('together', 'support'), 1)
# (('to', 'worked'), 1)
# (('to', 'together'), 1)
# (('to', 'support'), 1)
# (('to', 'the'), 1)
# (('support', 'together'), 1)
# (('support', 'to'), 1)
# (('support', 'the'), 1)
# (('support', 'glass'), 1)
# (('the', 'to'), 1)
# (('the', 'support'), 1)
# (('the', 'glass'), 1)
# (('the', 'firmly'), 1)
# (('glass', 'support'), 1)
# (('glass', 'the'), 1)
# (('glass', 'firmly'), 1)
# (('glass', 'in'), 1)
# (('firmly', 'the'), 1)
# (('firmly', 'glass'), 1)
# (('firmly', 'in'), 1)
# (('firmly', 'the'), 1)
# (('in', 'glass'), 1)
# (('in', 'firmly'), 1)
# (('in', 'the'), 1)
# (('in', 'sand'), 1)
# (('the', 'firmly'), 1)
# (('the', 'in'), 1)
# (('the', 'sand'), 1)
# (('the', 'when'), 1)
# (('sand', 'in'), 1)
# (('sand', 'the'), 1)
# (('sand', 'when'), 1)
# (('sand', 'they'), 1)
# (('when', 'the'), 1)
# (('when', 'sand'), 1)
# (('when', 'they'), 1)
# (('when', 'were'), 1)
# (('they', 'sand'), 1)
# (('they', 'when'), 1)
# (('they', 'were'), 1)
# (('they', 'finished'), 1)
# (('were', 'when'), 1)
# (('were', 'they'), 1)
# (('were', 'finished'), 1)
# (('were', 'they'), 1)
# (('finished', 'they'), 1)
# (('finished', 'were'), 1)
# (('finished', 'they'), 1)
# (('finished', 'both'), 1)
# (('they', 'were'), 1)
# (('they', 'finished'), 1)
# (('they', 'both'), 1)
# (('they', 'smiled'), 1)
# (('both', 'finished'), 1)
# (('both', 'they'), 1)
# (('both', 'smiled'), 1)
# (('both', 'at'), 1)
# (('smiled', 'they'), 1)
# (('smiled', 'both'), 1)
# (('smiled', 'at'), 1)
# (('smiled', 'the'), 1)
# (('at', 'both'), 1)
# (('at', 'smiled'), 1)
# (('at', 'the'), 1)
# (('at', 'incredible'), 1)
# (('the', 'smiled'), 1)
# (('the', 'at'), 1)
# (('the', 'incredible'), 1)
# (('the', 'thing'), 1)
# (('incredible', 'at'), 1)
# (('incredible', 'the'), 1)
# (('incredible', 'thing'), 1)
# (('incredible', 'they'), 1)
# (('thing', 'the'), 1)
# (('thing', 'incredible'), 1)
# (('thing', 'they'), 1)
# (('thing', 'had'), 1)
# (('they', 'incredible'), 1)
# (('they', 'thing'), 1)
# (('they', 'had'), 1)
# (('they', 'made'), 1)
# (('had', 'thing'), 1)
# (('had', 'they'), 1)
# (('had', 'made'), 1)
# (('had', 'once'), 1)
# (('made', 'they'), 1)
# (('made', 'had'), 1)
# (('made', 'once'), 1)
# (('made', 'upon'), 1)
# (('once', 'had'), 1)
# (('once', 'made'), 1)
# (('once', 'upon'), 1)
# (('once', 'a'), 1)
# (('upon', 'made'), 1)
# (('upon', 'once'), 1)
# (('upon', 'a'), 1)
# (('upon', 'time'), 1)
# (('a', 'once'), 1)
# (('a', 'upon'), 1)
# (('a', 'time'), 1)
# (('a', 'there'), 1)
# (('time', 'upon'), 1)
# (('time', 'a'), 1)
# (('time', 'there'), 1)
# (('time', 'was'), 1)
# (('there', 'a'), 1)
# (('there', 'time'), 1)
# (('there', 'was'), 1)
# (('there', 'a'), 1)
# (('was', 'time'), 1)
# (('was', 'there'), 1)
# (('was', 'a'), 1)
# (('was', 'team'), 1)
# (('a', 'there'), 1)
# (('a', 'was'), 1)
# (('a', 'team'), 1)
# (('a', 'of'), 1)
# (('team', 'was'), 1)
# (('team', 'a'), 1)
# (('team', 'of'), 1)
# (('team', 'animals'), 1)
# (('of', 'a'), 1)
# (('of', 'team'), 1)
# (('of', 'animals'), 1)
# (('of', 'who'), 1)
# (('animals', 'team'), 1)
# (('animals', 'of'), 1)
# (('animals', 'who'), 1)
# (('animals', 'wanted'), 1)
# (('who', 'of'), 1)
# (('who', 'animals'), 1)
# (('who', 'wanted'), 1)
# (('who', 'to'), 1)
# (('wanted', 'animals'), 1)
# (('wanted', 'who'), 1)
# (('wanted', 'to'), 1)
# (('wanted', 'climb'), 1)
# (('to', 'who'), 1)
# (('to', 'wanted'), 1)
# (('to', 'climb'), 1)
# (('to', 'a'), 1)
# (('climb', 'wanted'), 1)
# (('climb', 'to'), 1)
# (('climb', 'a'), 1)
# (('climb', 'big'), 1)
# (('a', 'to'), 1)
# (('a', 'climb'), 1)
# (('a', 'big'), 1)
# (('a', 'tree'), 1)
# (('big', 'climb'), 1)
# (('big', 'a'), 1)
# (('big', 'tree'), 1)
# (('big', 'they'), 1)
# (('tree', 'a'), 1)
# (('tree', 'big'), 1)
# (('tree', 'they'), 1)
# (('tree', 'tried'), 1)
# (('they', 'big'), 1)
# (('they', 'tree'), 1)
# (('they', 'tried'), 1)
# (('they', 'and'), 1)
# (('tried', 'tree'), 1)
# (('tried', 'they'), 1)
# (('tried', 'and'), 1)
# (('tried', 'tried'), 1)
# (('and', 'they'), 1)
# (('and', 'tried'), 1)
# (('and', 'tried'), 1)
# (('and', 'but'), 1)
# (('tried', 'tried'), 1)
# (('tried', 'and'), 1)
# (('tried', 'but'), 1)
# (('tried', 'it'), 1)
# (('but', 'and'), 1)
# (('but', 'tried'), 1)
# (('but', 'it'), 1)
# (('but', 'was'), 1)
# (('it', 'tried'), 1)
# (('it', 'but'), 1)
# (('it', 'was'), 1)
# (('it', 'too'), 1)
# (('was', 'but'), 1)
# (('was', 'it'), 1)
# (('was', 'too'), 1)
# (('was', 'hard'), 1)
# (('too', 'it'), 1)
# (('too', 'was'), 1)
# (('too', 'hard'), 1)
# (('too', 'they'), 1)
# (('hard', 'was'), 1)
# (('hard', 'too'), 1)
# (('hard', 'they'), 1)
# (('hard', 'were'), 1)
# (('they', 'too'), 1)
# (('they', 'hard'), 1)
# (('they', 'were'), 1)
# (('they', 'sad'), 1)
# (('were', 'hard'), 1)
# (('were', 'they'), 1)
# (('were', 'sad'), 1)
# (('were', 'and'), 1)
# (('sad', 'they'), 1)
# (('sad', 'were'), 1)
# (('sad', 'and'), 1)
# (('sad', 'didn'), 1)
# (('and', 'were'), 1)
# (('and', 'sad'), 1)
# (('and', 'didn'), 1)
# (('and', 't'), 1)
# (('didn', 'sad'), 1)
# (('didn', 'and'), 1)
# (('didn', 't'), 1)
# (('didn', 'know'), 1)
# (('t', 'and'), 1)
# (('t', 'didn'), 1)
# (('t', 'know'), 1)
# (('t', 'what'), 1)
# (('know', 'didn'), 1)
# (('know', 't'), 1)
# (('know', 'what'), 1)
# (('know', 'to'), 1)
# (('what', 't'), 1)
# (('what', 'know'), 1)
# (('what', 'to'), 1)
# (('what', 'do'), 1)
# (('to', 'know'), 1)
# (('to', 'what'), 1)
# (('to', 'do'), 1)
# (('to', 'one'), 1)
# (('do', 'what'), 1)
# (('do', 'to'), 1)
# (('do', 'one'), 1)
# (('do', 'day'), 1)
# (('one', 'to'), 1)
# (('one', 'do'), 1)
# (('one', 'day'), 1)
# (('one', 'a'), 1)
# (('day', 'do'), 1)
# (('day', 'one'), 1)
# (('day', 'a'), 1)
# (('day', 'clever'), 1)
# (('a', 'one'), 1)
# (('a', 'day'), 1)
# (('a', 'clever'), 1)
# (('a', 'squirrel'), 1)
# (('clever', 'day'), 1)
# (('clever', 'a'), 1)
# (('clever', 'squirrel'), 1)
# (('clever', 'saw'), 1)
# (('squirrel', 'a'), 1)
# (('squirrel', 'clever'), 1)
# (('squirrel', 'saw'), 1)
# (('squirrel', 'them'), 1)
# (('saw', 'clever'), 1)
# (('saw', 'squirrel'), 1)
# (('saw', 'them'), 1)
# (('saw', 'and'), 1)
# (('them', 'squirrel'), 1)
# (('them', 'saw'), 1)
# (('them', 'and'), 1)
# (('them', 'offered'), 1)
# (('and', 'saw'), 1)
# (('and', 'them'), 1)
# (('and', 'offered'), 1)
# (('and', 'to'), 1)
# (('offered', 'them'), 1)
# (('offered', 'and'), 1)
# (('offered', 'to'), 1)
# (('offered', 'help'), 1)
# (('to', 'and'), 1)
# (('to', 'offered'), 1)
# (('to', 'help'), 1)
# (('to', 'he'), 1)
# (('help', 'offered'), 1)
# (('help', 'to'), 1)
# (('help', 'he'), 1)
# (('help', 'told'), 1)
# (('he', 'to'), 1)
# (('he', 'help'), 1)
# (('he', 'told'), 1)
# (('he', 'them'), 1)
# (('told', 'help'), 1)
# (('told', 'he'), 1)
# (('told', 'them'), 1)
# (('told', 'to'), 1)
# (('them', 'he'), 1)
# (('them', 'told'), 1)
# (('them', 'to'), 1)
# (('them', 'work'), 1)
# (('to', 'told'), 1)
# (('to', 'them'), 1)
# (('to', 'work'), 1)
# (('to', 'together'), 1)
# (('work', 'them'), 1)
# (('work', 'to'), 1)
# (('work', 'together'), 1)
# (('work', 'as'), 1)
# (('together', 'to'), 1)
# (('together', 'work'), 1)
# (('together', 'as'), 1)
# (('together', 'a'), 1)
# (('as', 'work'), 1)
# (('as', 'together'), 1)
# (('as', 'a'), 1)
# (('as', 'team'), 1)
# (('a', 'together'), 1)
# (('a', 'as'), 1)
# (('a', 'team'), 1)
# (('a', 'and'), 1)
# (('team', 'as'), 1)
# (('team', 'a'), 1)
# (('team', 'and'), 1)
# (('team', 'climb'), 1)
# (('and', 'a'), 1)
# (('and', 'team'), 1)
# (('and', 'climb'), 1)
# (('and', 'on'), 1)
# (('climb', 'team'), 1)
# (('climb', 'and'), 1)
# (('climb', 'on'), 1)
# (('climb', 'each'), 1)
# (('on', 'and'), 1)
# (('on', 'climb'), 1)
# (('on', 'each'), 1)
# (('on', 'other'), 1)
# (('each', 'climb'), 1)
# (('each', 'on'), 1)
# (('each', 'other'), 1)
# (('each', 's'), 1)
# (('other', 'on'), 1)
# (('other', 'each'), 1)
# (('other', 's'), 1)
# (('other', 'backs'), 1)
# (('s', 'each'), 1)
# (('s', 'other'), 1)
# (('s', 'backs'), 1)
# (('s', 'at'), 1)
# (('backs', 'other'), 1)
# (('backs', 's'), 1)
# (('backs', 'at'), 1)
# (('backs', 'first'), 1)
# (('at', 's'), 1)
# (('at', 'backs'), 1)
# (('at', 'first'), 1)
# (('at', 'they'), 1)
# (('first', 'backs'), 1)
# (('first', 'at'), 1)
# (('first', 'they'), 1)
# (('first', 'were'), 1)
# (('they', 'at'), 1)
# (('they', 'first'), 1)
# (('they', 'were'), 1)
# (('they', 'unsure'), 1)
# (('were', 'first'), 1)
# (('were', 'they'), 1)
# (('were', 'unsure'), 1)
# (('were', 'but'), 1)
# (('unsure', 'they'), 1)
# (('unsure', 'were'), 1)
# (('unsure', 'but'), 1)
# (('unsure', 'they'), 1)
# (('but', 'were'), 1)
# (('but', 'unsure'), 1)
# (('but', 'they'), 1)
# (('but', 'decided'), 1)
# (('they', 'unsure'), 1)
# (('they', 'but'), 1)
# (('they', 'decided'), 1)
# (('they', 'to'), 1)
# (('decided', 'but'), 1)
# (('decided', 'they'), 1)
# (('decided', 'to'), 1)
# (('decided', 'try'), 1)
# (('to', 'they'), 1)
# (('to', 'decided'), 1)
# (('to', 'try'), 1)
# (('to', 'with'), 1)
# (('try', 'decided'), 1)
# (('try', 'to'), 1)
# (('try', 'with'), 1)
# (('try', 'the'), 1)
# (('with', 'to'), 1)
# (('with', 'try'), 1)
# (('with', 'the'), 1)
# (('with', 'squirrel'), 1)
# (('the', 'try'), 1)
# (('the', 'with'), 1)
# (('the', 'squirrel'), 1)
# (('the', 's'), 1)
# (('squirrel', 'with'), 1)
# (('squirrel', 'the'), 1)
# (('squirrel', 's'), 1)
# (('squirrel', 'guidance'), 1)
# (('s', 'the'), 1)
# (('s', 'squirrel'), 1)
# (('s', 'guidance'), 1)
# (('s', 'they'), 1)
# (('guidance', 'squirrel'), 1)
# (('guidance', 's'), 1)
# (('guidance', 'they'), 1)
# (('guidance', 'climbed'), 1)
# (('they', 's'), 1)
# (('they', 'guidance'), 1)
# (('they', 'climbed'), 1)
# (('they', 'higher'), 1)
# (('climbed', 'guidance'), 1)
# (('climbed', 'they'), 1)
# (('climbed', 'higher'), 1)
# (('climbed', 'and'), 1)
# (('higher', 'they'), 1)
# (('higher', 'climbed'), 1)
# (('higher', 'and'), 1)
# (('higher', 'higher'), 1)
# (('and', 'climbed'), 1)
# (('and', 'higher'), 1)
# (('and', 'higher'), 1)
# (('and', 'until'), 1)
# (('higher', 'higher'), 1)
# (('higher', 'and'), 1)
# (('higher', 'until'), 1)
# (('higher', 'they'), 1)
# (('until', 'and'), 1)
# (('until', 'higher'), 1)
# (('until', 'they'), 1)
# (('until', 'reached'), 1)
# (('they', 'higher'), 1)
# (('they', 'until'), 1)
# (('they', 'reached'), 1)
# (('they', 'the'), 1)
# (('reached', 'until'), 1)
# (('reached', 'they'), 1)
# (('reached', 'the'), 1)
# (('reached', 'top'), 1)
# (('the', 'they'), 1)
# (('the', 'reached'), 1)
# (('the', 'top'), 1)
# (('the', 'they'), 1)
# (('top', 'reached'), 1)
# (('top', 'the'), 1)
# (('top', 'they'), 1)
# (('top', 'were'), 1)
# (('they', 'the'), 1)
# (('they', 'top'), 1)
# (('they', 'were'), 1)
# (('they', 'so'), 1)
# (('were', 'top'), 1)
# (('were', 'they'), 1)
# (('were', 'so'), 1)
# (('were', 'happy'), 1)
# (('so', 'they'), 1)
# (('so', 'were'), 1)
# (('so', 'happy'), 1)
# (('so', 'and'), 1)
# (('happy', 'were'), 1)
# (('happy', 'so'), 1)
# (('happy', 'and'), 1)
# (('happy', 'proud'), 1)
# (('and', 'so'), 1)
# (('and', 'happy'), 1)
# (('and', 'proud'), 1)
# (('and', 'of'), 1)
# (('proud', 'happy'), 1)
# (('proud', 'and'), 1)
# (('proud', 'of'), 1)
# (('proud', 'themselves'), 1)
# (('of', 'and'), 1)
# (('of', 'proud'), 1)
# (('of', 'themselves'), 1)
# (('of', 'for'), 1)
# (('themselves', 'proud'), 1)
# (('themselves', 'of'), 1)
# (('themselves', 'for'), 1)
# (('themselves', 'working'), 1)
# (('for', 'of'), 1)
# (('for', 'themselves'), 1)
# (('for', 'working'), 1)
# (('for', 'hard'), 1)
# (('working', 'themselves'), 1)
# (('working', 'for'), 1)
# (('working', 'hard'), 1)
# (('working', 'as'), 1)
# (('hard', 'for'), 1)
# (('hard', 'working'), 1)
# (('hard', 'as'), 1)
# (('hard', 'a'), 1)
# (('as', 'working'), 1)
# (('as', 'hard'), 1)
# (('as', 'a'), 1)
# (('as', 'team'), 1)
# (('a', 'hard'), 1)
# (('a', 'as'), 1)
# (('a', 'team'), 1)
# (('a', 'from'), 1)
# (('team', 'as'), 1)
# (('team', 'a'), 1)
# (('team', 'from'), 1)
# (('team', 'that'), 1)
# (('from', 'a'), 1)
# (('from', 'team'), 1)
# (('from', 'that'), 1)
# (('from', 'day'), 1)
# (('that', 'team'), 1)
# (('that', 'from'), 1)
# (('that', 'day'), 1)
# (('that', 'on'), 1)
# (('day', 'from'), 1)
# (('day', 'that'), 1)
# (('day', 'on'), 1)
# (('day', 'they'), 1)
# (('on', 'that'), 1)
# (('on', 'day'), 1)
# (('on', 'they'), 1)
# (('on', 'knew'), 1)
# (('they', 'day'), 1)
# (('they', 'on'), 1)
# (('they', 'knew'), 1)
# (('they', 'that'), 1)
# (('knew', 'on'), 1)
# (('knew', 'they'), 1)
# (('knew', 'that'), 1)
# (('knew', 'anything'), 1)
# (('that', 'they'), 1)
# (('that', 'knew'), 1)
# (('that', 'anything'), 1)
# (('that', 'was'), 1)
# (('anything', 'knew'), 1)
# (('anything', 'that'), 1)
# (('anything', 'was'), 1)
# (('anything', 'possible'), 1)
# (('was', 'that'), 1)
# (('was', 'anything'), 1)
# (('was', 'possible'), 1)
# (('was', 'if'), 1)
# (('possible', 'anything'), 1)
# (('possible', 'was'), 1)
# (('possible', 'if'), 1)
# (('possible', 'they'), 1)
# (('if', 'was'), 1)
# (('if', 'possible'), 1)
# (('if', 'they'), 1)
# (('if', 'worked'), 1)
# (('they', 'possible'), 1)
# (('they', 'if'), 1)
# (('they', 'worked'), 1)
# (('they', 'together'), 1)
# (('worked', 'if'), 1)
# (('worked', 'they'), 1)
# (('worked', 'together'), 1)
# (('worked', 'and'), 1)
# (('together', 'they'), 1)
# (('together', 'worked'), 1)
# (('together', 'and'), 1)
# (('together', 'didn'), 1)
# (('and', 'worked'), 1)
# (('and', 'together'), 1)
# (('and', 'didn'), 1)
# (('and', 't'), 1)
# (('didn', 'together'), 1)
# (('didn', 'and'), 1)
# (('didn', 't'), 1)
# (('didn', 'give'), 1)
# (('t', 'and'), 1)
# (('t', 'didn'), 1)
# (('t', 'give'), 1)
# (('t', 'up'), 1)
# (('give', 'didn'), 1)
# (('give', 't'), 1)
# (('give', 'up'), 1)
# (('give', 'once'), 1)
# (('up', 't'), 1)
# (('up', 'give'), 1)
# (('up', 'once'), 1)
# (('up', 'upon'), 1)
# (('once', 'give'), 1)
# (('once', 'up'), 1)
# (('once', 'upon'), 1)
# (('once', 'a'), 1)
# (('upon', 'up'), 1)
# (('upon', 'once'), 1)
# (('upon', 'a'), 1)
# (('upon', 'time'), 1)
# (('a', 'once'), 1)
# (('a', 'upon'), 1)
# (('a', 'time'), 1)
# (('a', 'there'), 1)
# (('time', 'upon'), 1)
# (('time', 'a'), 1)
# (('time', 'there'), 1)
# (('time', 'was'), 1)
# (('there', 'a'), 1)
# (('there', 'time'), 1)
# (('there', 'was'), 1)
# (('there', 'a'), 1)
# (('was', 'time'), 1)
# (('was', 'there'), 1)
# (('was', 'a'), 1)
# (('was', 'little'), 1)
# (('a', 'there'), 1)
# (('a', 'was'), 1)
# (('a', 'little'), 1)
# (('a', 'boy'), 1)
# (('little', 'was'), 1)
# (('little', 'a'), 1)
# (('little', 'boy'), 1)
# (('little', 'named'), 1)
# (('boy', 'a'), 1)
# (('boy', 'little'), 1)
# (('boy', 'named'), 1)
# (('boy', 'timmy'), 1)
# (('named', 'little'), 1)
# (('named', 'boy'), 1)
# (('named', 'timmy'), 1)
# (('named', 'timmy'), 1)
# (('timmy', 'boy'), 1)
# (('timmy', 'named'), 1)
# (('timmy', 'timmy'), 1)
# (('timmy', 'loved'), 1)
# (('timmy', 'named'), 1)
# (('timmy', 'timmy'), 1)
# (('timmy', 'loved'), 1)
# (('timmy', 'playing'), 1)
# (('loved', 'timmy'), 1)
# (('loved', 'timmy'), 1)
# (('loved', 'playing'), 1)
# (('loved', 'with'), 1)
# (('playing', 'timmy'), 1)
# (('playing', 'loved'), 1)
# (('playing', 'with'), 1)
# (('playing', 'his'), 1)
# (('with', 'loved'), 1)
# (('with', 'playing'), 1)
# (('with', 'his'), 1)
# (('with', 'toys'), 1)
# (('his', 'playing'), 1)
# (('his', 'with'), 1)
# (('his', 'toys'), 1)
# (('his', 'but'), 1)
# (('toys', 'with'), 1)
# (('toys', 'his'), 1)
# (('toys', 'but'), 1)
# (('toys', 'he'), 1)
# (('but', 'his'), 1)
# (('but', 'toys'), 1)
# (('but', 'he'), 1)
# (('but', 'was'), 1)
# (('he', 'toys'), 1)
# (('he', 'but'), 1)
# (('he', 'was'), 1)
# (('he', 'very'), 1)
# (('was', 'but'), 1)
# (('was', 'he'), 1)
# (('was', 'very'), 1)
# (('was', 'careless'), 1)
# (('very', 'he'), 1)
# (('very', 'was'), 1)
# (('very', 'careless'), 1)
# (('very', 'with'), 1)
# (('careless', 'was'), 1)
# (('careless', 'very'), 1)
# (('careless', 'with'), 1)
# (('careless', 'them'), 1)
# (('with', 'very'), 1)
# (('with', 'careless'), 1)
# (('with', 'them'), 1)
# (('with', 'he'), 1)
# (('them', 'careless'), 1)
# (('them', 'with'), 1)
# (('them', 'he'), 1)
# (('them', 'would'), 1)
# (('he', 'with'), 1)
# (('he', 'them'), 1)
# (('he', 'would'), 1)
# (('he', 'leave'), 1)
# (('would', 'them'), 1)
# (('would', 'he'), 1)
# (('would', 'leave'), 1)
# (('would', 'them'), 1)
# (('leave', 'he'), 1)
# (('leave', 'would'), 1)
# (('leave', 'them'), 1)
# (('leave', 'all'), 1)
# (('them', 'would'), 1)
# (('them', 'leave'), 1)
# (('them', 'all'), 1)
# (('them', 'over'), 1)
# (('all', 'leave'), 1)
# (('all', 'them'), 1)
# (('all', 'over'), 1)
# (('all', 'the'), 1)
# (('over', 'them'), 1)
# (('over', 'all'), 1)
# (('over', 'the'), 1)
# (('over', 'house'), 1)
# (('the', 'all'), 1)
# (('the', 'over'), 1)
# (('the', 'house'), 1)
# (('the', 'and'), 1)
# (('house', 'over'), 1)
# (('house', 'the'), 1)
# (('house', 'and'), 1)
# (('house', 'sometimes'), 1)
# (('and', 'the'), 1)
# (('and', 'house'), 1)
# (('and', 'sometimes'), 1)
# (('and', 'even'), 1)
# (('sometimes', 'house'), 1)
# (('sometimes', 'and'), 1)
# (('sometimes', 'even'), 1)
# (('sometimes', 'step'), 1)
# (('even', 'and'), 1)
# (('even', 'sometimes'), 1)
# (('even', 'step'), 1)
# (('even', 'on'), 1)
# (('step', 'sometimes'), 1)
# (('step', 'even'), 1)
# (('step', 'on'), 1)
# (('step', 'them'), 1)
# (('on', 'even'), 1)
# (('on', 'step'), 1)
# (('on', 'them'), 1)
# (('on', 'one'), 1)
# (('them', 'step'), 1)
# (('them', 'on'), 1)
# (('them', 'one'), 1)
# (('them', 'day'), 1)
# (('one', 'on'), 1)
# (('one', 'them'), 1)
# (('one', 'day'), 1)
# (('one', 'timmy'), 1)
# (('day', 'them'), 1)
# (('day', 'one'), 1)
# (('day', 'timmy'), 1)
# (('day', 's'), 1)
# (('timmy', 'one'), 1)
# (('timmy', 'day'), 1)
# (('timmy', 's'), 1)
# (('timmy', 'mother'), 1)
# (('s', 'day'), 1)
# (('s', 'timmy'), 1)
# (('s', 'mother'), 1)
# (('s', 'asked'), 1)
# (('mother', 'timmy'), 1)
# (('mother', 's'), 1)
# (('mother', 'asked'), 1)
# (('mother', 'him'), 1)
# (('asked', 's'), 1)
# (('asked', 'mother'), 1)
# (('asked', 'him'), 1)
# (('asked', 'to'), 1)
# (('him', 'mother'), 1)
# (('him', 'asked'), 1)
# (('him', 'to'), 1)
# (('him', 'help'), 1)
# (('to', 'asked'), 1)
# (('to', 'him'), 1)
# (('to', 'help'), 1)
# (('to', 'her'), 1)
# (('help', 'him'), 1)
# (('help', 'to'), 1)
# (('help', 'her'), 1)
# (('help', 'with'), 1)
# (('her', 'to'), 1)
# (('her', 'help'), 1)
# (('her', 'with'), 1)
# (('her', 'the'), 1)
# (('with', 'help'), 1)
# (('with', 'her'), 1)
# (('with', 'the'), 1)
# (('with', 'laundry'), 1)
# (('the', 'her'), 1)
# (('the', 'with'), 1)
# (('the', 'laundry'), 1)
# (('the', 'timmy'), 1)
# (('laundry', 'with'), 1)
# (('laundry', 'the'), 1)
# (('laundry', 'timmy'), 1)
# (('laundry', 'didn'), 1)
# (('timmy', 'the'), 1)
# (('timmy', 'laundry'), 1)
# (('timmy', 'didn'), 1)
# (('timmy', 't'), 1)
# (('didn', 'laundry'), 1)
# (('didn', 'timmy'), 1)
# (('didn', 't'), 1)
# (('didn', 'want'), 1)
# (('t', 'timmy'), 1)
# (('t', 'didn'), 1)
# (('t', 'want'), 1)
# (('t', 'to'), 1)
# (('want', 'didn'), 1)
# (('want', 't'), 1)
# (('want', 'to'), 1)
# (('want', 'help'), 1)
# (('to', 't'), 1)
# (('to', 'want'), 1)
# (('to', 'help'), 1)
# (('to', 'but'), 1)
# (('help', 'want'), 1)
# (('help', 'to'), 1)
# (('help', 'but'), 1)
# (('help', 'his'), 1)
# (('but', 'to'), 1)
# (('but', 'help'), 1)
# (('but', 'his'), 1)
# (('but', 'mother'), 1)
# (('his', 'help'), 1)
# (('his', 'but'), 1)
# (('his', 'mother'), 1)
# (('his', 'said'), 1)
# (('mother', 'but'), 1)
# (('mother', 'his'), 1)
# (('mother', 'said'), 1)
# (('mother', 'he'), 1)
# (('said', 'his'), 1)
# (('said', 'mother'), 1)
# (('said', 'he'), 1)
# (('said', 'had'), 1)
# (('he', 'mother'), 1)
# (('he', 'said'), 1)
# (('he', 'had'), 1)
# (('he', 'to'), 1)
# (('had', 'said'), 1)
# (('had', 'he'), 1)
# (('had', 'to'), 1)
# (('had', 'timmy'), 1)
# (('to', 'he'), 1)
# (('to', 'had'), 1)
# (('to', 'timmy'), 1)
# (('to', 'was'), 1)
# (('timmy', 'had'), 1)
# (('timmy', 'to'), 1)
# (('timmy', 'was'), 1)
# (('timmy', 'grumpy'), 1)
# (('was', 'to'), 1)
# (('was', 'timmy'), 1)
# (('was', 'grumpy'), 1)
# (('was', 'and'), 1)
# (('grumpy', 'timmy'), 1)
# (('grumpy', 'was'), 1)
# (('grumpy', 'and'), 1)
# (('grumpy', 'didn'), 1)
# (('and', 'was'), 1)
# (('and', 'grumpy'), 1)
# (('and', 'didn'), 1)
# (('and', 't'), 1)
# (('didn', 'grumpy'), 1)
# (('didn', 'and'), 1)
# (('didn', 't'), 1)
# (('didn', 'yield'), 1)
# (('t', 'and'), 1)
# (('t', 'didn'), 1)
# (('t', 'yield'), 1)
# (('t', 'to'), 1)
# (('yield', 'didn'), 1)
# (('yield', 't'), 1)
# (('yield', 'to'), 1)
# (('yield', 'his'), 1)
# (('to', 't'), 1)
# (('to', 'yield'), 1)
# (('to', 'his'), 1)
# (('to', 'mother'), 1)
# (('his', 'yield'), 1)
# (('his', 'to'), 1)
# (('his', 'mother'), 1)
# (('his', 's'), 1)
# (('mother', 'to'), 1)
# (('mother', 'his'), 1)
# (('mother', 's'), 1)
# (('mother', 'request'), 1)
# (('s', 'his'), 1)
# (('s', 'mother'), 1)
# (('s', 'request'), 1)
# (('s', 'while'), 1)
# (('request', 'mother'), 1)
# (('request', 's'), 1)
# (('request', 'while'), 1)
# (('request', 'helping'), 1)
# (('while', 's'), 1)
# (('while', 'request'), 1)
# (('while', 'helping'), 1)
# (('while', 'with'), 1)
# (('helping', 'request'), 1)
# (('helping', 'while'), 1)
# (('helping', 'with'), 1)
# (('helping', 'the'), 1)
# (('with', 'while'), 1)
# (('with', 'helping'), 1)
# (('with', 'the'), 1)
# (('with', 'laundry'), 1)
# (('the', 'helping'), 1)
# (('the', 'with'), 1)
# (('the', 'laundry'), 1)
# (('the', 'timmy'), 1)
# (('laundry', 'with'), 1)
# (('laundry', 'the'), 1)
# (('laundry', 'timmy'), 1)
# (('laundry', 'accidentally'), 1)
# (('timmy', 'the'), 1)
# (('timmy', 'laundry'), 1)
# (('timmy', 'accidentally'), 1)
# (('timmy', 'spilled'), 1)
# (('accidentally', 'laundry'), 1)
# (('accidentally', 'timmy'), 1)
# (('accidentally', 'spilled'), 1)
# (('accidentally', 'coal'), 1)
# (('spilled', 'timmy'), 1)
# (('spilled', 'accidentally'), 1)
# (('spilled', 'coal'), 1)
# (('spilled', 'all'), 1)
# (('coal', 'accidentally'), 1)
# (('coal', 'spilled'), 1)
# (('coal', 'all'), 1)
# (('coal', 'over'), 1)
# (('all', 'spilled'), 1)
# (('all', 'coal'), 1)
# (('all', 'over'), 1)
# (('all', 'the'), 1)
# (('over', 'coal'), 1)
# (('over', 'all'), 1)
# (('over', 'the'), 1)
# (('over', 'clean'), 1)
# (('the', 'all'), 1)
# (('the', 'over'), 1)
# (('the', 'clean'), 1)
# (('the', 'clothes'), 1)
# (('clean', 'over'), 1)
# (('clean', 'the'), 1)
# (('clean', 'clothes'), 1)
# (('clean', 'his'), 1)
# (('clothes', 'the'), 1)
# (('clothes', 'clean'), 1)
# (('clothes', 'his'), 1)
# (('clothes', 'mother'), 1)
# (('his', 'clean'), 1)
# (('his', 'clothes'), 1)
# (('his', 'mother'), 1)
# (('his', 'was'), 1)
# (('mother', 'clothes'), 1)
# (('mother', 'his'), 1)
# (('mother', 'was'), 1)
# (('mother', 'very'), 1)
# (('was', 'his'), 1)
# (('was', 'mother'), 1)
# (('was', 'very'), 1)
# (('was', 'upset'), 1)
# (('very', 'mother'), 1)
# (('very', 'was'), 1)
# (('very', 'upset'), 1)
# (('very', 'and'), 1)
# (('upset', 'was'), 1)
# (('upset', 'very'), 1)
# (('upset', 'and'), 1)
# (('upset', 'timmy'), 1)
# (('and', 'very'), 1)
# (('and', 'upset'), 1)
# (('and', 'timmy'), 1)
# (('and', 'felt'), 1)
# (('timmy', 'upset'), 1)
# (('timmy', 'and'), 1)
# (('timmy', 'felt'), 1)
# (('timmy', 'bad'), 1)
# (('felt', 'and'), 1)
# (('felt', 'timmy'), 1)
# (('felt', 'bad'), 1)
# (('felt', 'he'), 1)
# (('bad', 'timmy'), 1)
# (('bad', 'felt'), 1)
# (('bad', 'he'), 1)
# (('bad', 'realized'), 1)
# (('he', 'felt'), 1)
# (('he', 'bad'), 1)
# (('he', 'realized'), 1)
# (('he', 'that'), 1)
# (('realized', 'bad'), 1)
# (('realized', 'he'), 1)
# (('realized', 'that'), 1)
# (('realized', 'being'), 1)
# (('that', 'he'), 1)
# (('that', 'realized'), 1)
# (('that', 'being'), 1)
# (('that', 'careless'), 1)
# (('being', 'realized'), 1)
# (('being', 'that'), 1)
# (('being', 'careless'), 1)
# (('being', 'wasn'), 1)
# (('careless', 'that'), 1)
# (('careless', 'being'), 1)
# (('careless', 'wasn'), 1)
# (('careless', 't'), 1)
# (('wasn', 'being'), 1)
# (('wasn', 'careless'), 1)
# (('wasn', 't'), 1)
# (('wasn', 'good'), 1)
# (('t', 'careless'), 1)
# (('t', 'wasn'), 1)
# (('t', 'good'), 1)
# (('t', 'and'), 1)
# (('good', 'wasn'), 1)
# (('good', 't'), 1)
# (('good', 'and'), 1)
# (('good', 'promised'), 1)
# (('and', 't'), 1)
# (('and', 'good'), 1)
# (('and', 'promised'), 1)
# (('and', 'to'), 1)
# (('promised', 'good'), 1)
# (('promised', 'and'), 1)
# (('promised', 'to'), 1)
# (('promised', 'be'), 1)
# (('to', 'and'), 1)
# (('to', 'promised'), 1)
# (('to', 'be'), 1)
# (('to', 'more'), 1)
# (('be', 'promised'), 1)
# (('be', 'to'), 1)
# (('be', 'more'), 1)
# (('be', 'careful'), 1)
# (('more', 'to'), 1)
# (('more', 'be'), 1)
# (('more', 'careful'), 1)
# (('more', 'with'), 1)
# (('careful', 'be'), 1)
# (('careful', 'more'), 1)
# (('careful', 'with'), 1)
# (('careful', 'his'), 1)
# (('with', 'more'), 1)
# (('with', 'careful'), 1)
# (('with', 'his'), 1)
# (('with', 'toys'), 1)
# (('his', 'careful'), 1)
# (('his', 'with'), 1)
# (('his', 'toys'), 1)
# (('his', 'and'), 1)
# (('toys', 'with'), 1)
# (('toys', 'his'), 1)
# (('toys', 'and'), 1)
# (('toys', 'help'), 1)
# (('and', 'his'), 1)
# (('and', 'toys'), 1)
# (('and', 'help'), 1)
# (('and', 'his'), 1)
# (('help', 'toys'), 1)
# (('help', 'and'), 1)
# (('help', 'his'), 1)
# (('help', 'mother'), 1)
# (('his', 'and'), 1)
# (('his', 'help'), 1)
# (('his', 'mother'), 1)
# (('his', 'more'), 1)
# (('mother', 'help'), 1)
# (('mother', 'his'), 1)
# (('mother', 'more'), 1)
# (('mother', 'often'), 1)
# (('more', 'his'), 1)
# (('more', 'mother'), 1)
# (('more', 'often'), 1)
# (('more', 'the'), 1)
# (('often', 'mother'), 1)
# (('often', 'more'), 1)
# (('often', 'the'), 1)
# (('often', 'moral'), 1)
# (('the', 'more'), 1)
# (('the', 'often'), 1)
# (('the', 'moral'), 1)
# (('the', 'of'), 1)
# (('moral', 'often'), 1)
# (('moral', 'the'), 1)
# (('moral', 'of'), 1)
# (('moral', 'the'), 1)
# (('of', 'the'), 1)
# (('of', 'moral'), 1)
# (('of', 'the'), 1)
# (('of', 'story'), 1)
# (('the', 'moral'), 1)
# (('the', 'of'), 1)
# (('the', 'story'), 1)
# (('the', 'is'), 1)
# (('story', 'of'), 1)
# (('story', 'the'), 1)
# (('story', 'is'), 1)
# (('story', 'that'), 1)
# (('is', 'the'), 1)
# (('is', 'story'), 1)
# (('is', 'that'), 1)
# (('is', 'we'), 1)
# (('that', 'story'), 1)
# (('that', 'is'), 1)
# (('that', 'we'), 1)
# (('that', 'should'), 1)
# (('we', 'is'), 1)
# (('we', 'that'), 1)
# (('we', 'should'), 1)
# (('we', 'be'), 1)
# (('should', 'that'), 1)
# (('should', 'we'), 1)
# (('should', 'be'), 1)
# (('should', 'careful'), 1)
# (('be', 'we'), 1)
# (('be', 'should'), 1)
# (('be', 'careful'), 1)
# (('be', 'with'), 1)
# (('careful', 'should'), 1)
# (('careful', 'be'), 1)
# (('careful', 'with'), 1)
# (('careful', 'our'), 1)
# (('with', 'be'), 1)
# (('with', 'careful'), 1)
# (('with', 'our'), 1)
# (('with', 'things'), 1)
# (('our', 'careful'), 1)
# (('our', 'with'), 1)
# (('our', 'things'), 1)
# (('our', 'and'), 1)
# (('things', 'with'), 1)
# (('things', 'our'), 1)
# (('things', 'and'), 1)
# (('things', 'help'), 1)
# (('and', 'our'), 1)
# (('and', 'things'), 1)
# (('and', 'help'), 1)
# (('and', 'others'), 1)
# (('help', 'things'), 1)
# (('help', 'and'), 1)
# (('help', 'others'), 1)
# (('help', 'when'), 1)
# (('others', 'and'), 1)
# (('others', 'help'), 1)
# (('others', 'when'), 1)
# (('others', 'we'), 1)
# (('when', 'help'), 1)
# (('when', 'others'), 1)
# (('when', 'we'), 1)
# (('when', 'can'), 1)
# (('we', 'others'), 1)
# (('we', 'when'), 1)
# (('we', 'can'), 1)
# (('we', 'once'), 1)
# (('can', 'when'), 1)
# (('can', 'we'), 1)
# (('can', 'once'), 1)
# (('can', 'upon'), 1)
# (('once', 'we'), 1)
# (('once', 'can'), 1)
# (('once', 'upon'), 1)
# (('once', 'a'), 1)
# (('upon', 'can'), 1)
# (('upon', 'once'), 1)
# (('upon', 'a'), 1)
# ...
# (('a', 'picture'), 1)
# (('a', 'of'), 1)
# (('picture', 'printed'), 1)
# (('picture', 'a'), 1)
# (('picture', 'of'), 1)
# (('picture', 'his'), 1)
# (('of', 'a'), 1)
# (('of', 'picture'), 1)
# (('of', 'his'), 1)
# (('of', 'wife'), 1)
# (('his', 'picture'), 1)
# (('his', 'of'), 1)
# (('his', 'wife'), 1)
# (('his', 'but'), 1)
# (('wife', 'of'), 1)
# (('wife', 'his'), 1)
# (('wife', 'but'), 1)
# (('wife', 'it'), 1)
# (('but', 'his'), 1)
# (('but', 'wife'), 1)
# (('but', 'it'), 1)
# (('but', 'looked'), 1)
# (('it', 'wife'), 1)
# (('it', 'but'), 1)
# (('it', 'looked'), 1)
# (('it', 'unusual'), 1)
# (('looked', 'but'), 1)
# (('looked', 'it'), 1)
# (('looked', 'unusual'), 1)
# (('looked', 'he'), 1)
# (('unusual', 'it'), 1)
# (('unusual', 'looked'), 1)
# (('unusual', 'he'), 1)
# (('unusual', 'asked'), 1)
# (('he', 'looked'), 1)
# (('he', 'unusual'), 1)
# (('he', 'asked'), 1)
# (('he', 'his'), 1)
# (('asked', 'unusual'), 1)
# (('asked', 'he'), 1)
# (('asked', 'his'), 1)
# (('asked', 'son'), 1)
# (('his', 'he'), 1)
# (('his', 'asked'), 1)
# (('his', 'son'), 1)
# (('his', 'why'), 1)
# (('son', 'asked'), 1)
# (('son', 'his'), 1)
# (('son', 'why'), 1)
# (('son', 'does'), 1)
# (('why', 'his'), 1)
# (('why', 'son'), 1)
# (('why', 'does'), 1)
# (('why', 'the'), 1)
# (('does', 'son'), 1)
# (('does', 'why'), 1)
# (('does', 'the'), 1)
# (('does', 'picture'), 1)
# (('the', 'why'), 1)
# (('the', 'does'), 1)
# (('the', 'picture'), 1)
# (('the', 'look'), 1)
# (('picture', 'does'), 1)
# (('picture', 'the'), 1)
# (('picture', 'look'), 1)
# (('picture', 'unusual'), 1)
# (('look', 'the'), 1)
# (('look', 'picture'), 1)
# (('look', 'unusual'), 1)
# (('look', 'the'), 1)
# (('unusual', 'picture'), 1)
# (('unusual', 'look'), 1)
# (('unusual', 'the'), 1)
# (('unusual', 'son'), 1)
# (('the', 'look'), 1)
# (('the', 'unusual'), 1)
# (('the', 'son'), 1)
# (('the', 'replied'), 1)
# (('son', 'unusual'), 1)
# (('son', 'the'), 1)
# (('son', 'replied'), 1)
# (('son', 'maybe'), 1)
# (('replied', 'the'), 1)
# (('replied', 'son'), 1)
# (('replied', 'maybe'), 1)
# (('replied', 'the'), 1)
# (('maybe', 'son'), 1)
# (('maybe', 'replied'), 1)
# (('maybe', 'the'), 1)
# (('maybe', 'printer'), 1)
# (('the', 'replied'), 1)
# (('the', 'maybe'), 1)
# (('the', 'printer'), 1)
# (('the', 'is'), 1)
# (('printer', 'maybe'), 1)
# (('printer', 'the'), 1)
# (('printer', 'is'), 1)
# (('printer', 'broken'), 1)
# (('is', 'the'), 1)
# (('is', 'printer'), 1)
# (('is', 'broken'), 1)
# (('is', 'daddy'), 1)
# (('broken', 'printer'), 1)
# (('broken', 'is'), 1)
# (('broken', 'daddy'), 1)
# (('broken', 'the'), 1)
# (('daddy', 'is'), 1)
# (('daddy', 'broken'), 1)
# (('daddy', 'the'), 1)
# (('daddy', 'man'), 1)
# (('the', 'broken'), 1)
# (('the', 'daddy'), 1)
# (('the', 'man'), 1)
# (('the', 'tried'), 1)
# (('man', 'daddy'), 1)
# (('man', 'the'), 1)
# (('man', 'tried'), 1)
# (('man', 'to'), 1)
# (('tried', 'the'), 1)
# (('tried', 'man'), 1)
# (('tried', 'to'), 1)
# (('tried', 'fix'), 1)
# (('to', 'man'), 1)
# (('to', 'tried'), 1)
# (('to', 'fix'), 1)
# (('to', 'the'), 1)
# (('fix', 'tried'), 1)
# (('fix', 'to'), 1)
# (('fix', 'the'), 1)
# (('fix', 'printer'), 1)
# (('the', 'to'), 1)
# (('the', 'fix'), 1)
# (('the', 'printer'), 1)
# (('the', 'but'), 1)
# (('printer', 'fix'), 1)
# (('printer', 'the'), 1)
# (('printer', 'but'), 1)
# (('printer', 'he'), 1)
# (('but', 'the'), 1)
# (('but', 'printer'), 1)
# (('but', 'he'), 1)
# (('but', 'couldn'), 1)
# (('he', 'printer'), 1)
# (('he', 'but'), 1)
# (('he', 'couldn'), 1)
# (('he', 't'), 1)
# (('couldn', 'but'), 1)
# (('couldn', 'he'), 1)
# (('couldn', 't'), 1)
# (('couldn', 'he'), 1)
# (('t', 'he'), 1)
# (('t', 'couldn'), 1)
# (('t', 'he'), 1)
# (('t', 'asked'), 1)
# (('he', 'couldn'), 1)
# (('he', 't'), 1)
# (('he', 'asked'), 1)
# (('he', 'his'), 1)
# (('asked', 't'), 1)
# (('asked', 'he'), 1)
# (('asked', 'his'), 1)
# (('asked', 'son'), 1)
# (('his', 'he'), 1)
# (('his', 'asked'), 1)
# (('his', 'son'), 1)
# (('his', 'do'), 1)
# (('son', 'asked'), 1)
# (('son', 'his'), 1)
# (('son', 'do'), 1)
# (('son', 'you'), 1)
# (('do', 'his'), 1)
# (('do', 'son'), 1)
# (('do', 'you'), 1)
# (('do', 'know'), 1)
# (('you', 'son'), 1)
# (('you', 'do'), 1)
# (('you', 'know'), 1)
# (('you', 'how'), 1)
# (('know', 'do'), 1)
# (('know', 'you'), 1)
# (('know', 'how'), 1)
# (('know', 'to'), 1)
# (('how', 'you'), 1)
# (('how', 'know'), 1)
# (('how', 'to'), 1)
# (('how', 'fix'), 1)
# (('to', 'know'), 1)
# (('to', 'how'), 1)
# (('to', 'fix'), 1)
# (('to', 'the'), 1)
# (('fix', 'how'), 1)
# (('fix', 'to'), 1)
# (('fix', 'the'), 1)
# (('fix', 'printer'), 1)
# (('the', 'to'), 1)
# (('the', 'fix'), 1)
# (('the', 'printer'), 1)
# (('the', 'the'), 1)
# (('printer', 'fix'), 1)
# (('printer', 'the'), 1)
# (('printer', 'the'), 1)
# (('printer', 'son'), 1)
# (('the', 'the'), 1)
# (('the', 'printer'), 1)
# (('the', 'son'), 1)
# (('the', 'replied'), 1)
# (('son', 'printer'), 1)
# (('son', 'the'), 1)
# (('son', 'replied'), 1)
# (('son', 'no'), 1)
# (('replied', 'the'), 1)
# (('replied', 'son'), 1)
# (('replied', 'no'), 1)
# (('replied', 'daddy'), 1)
# (('no', 'son'), 1)
# (('no', 'replied'), 1)
# (('no', 'daddy'), 1)
# (('no', 'but'), 1)
# (('daddy', 'replied'), 1)
# (('daddy', 'no'), 1)
# (('daddy', 'but'), 1)
# (('daddy', 'we'), 1)
# (('but', 'no'), 1)
# (('but', 'daddy'), 1)
# (('but', 'we'), 1)
# (('but', 'can'), 1)
# (('we', 'daddy'), 1)
# (('we', 'but'), 1)
# (('we', 'can'), 1)
# (('we', 'buy'), 1)
# (('can', 'but'), 1)
# (('can', 'we'), 1)
# (('can', 'buy'), 1)
# (('can', 'a'), 1)
# (('buy', 'we'), 1)
# (('buy', 'can'), 1)
# (('buy', 'a'), 1)
# (('buy', 'new'), 1)
# (('a', 'can'), 1)
# (('a', 'buy'), 1)
# (('a', 'new'), 1)
# (('a', 'one'), 1)
# (('new', 'buy'), 1)
# (('new', 'a'), 1)
# (('new', 'one'), 1)
# (('new', 'and'), 1)
# (('one', 'a'), 1)
# (('one', 'new'), 1)
# (('one', 'and'), 1)
# (('one', 'so'), 1)
# (('and', 'new'), 1)
# (('and', 'one'), 1)
# (('and', 'so'), 1)
# (('and', 'they'), 1)
# (('so', 'one'), 1)
# (('so', 'and'), 1)
# (('so', 'they'), 1)
# (('so', 'went'), 1)
# (('they', 'and'), 1)
# (('they', 'so'), 1)
# (('they', 'went'), 1)
# (('they', 'to'), 1)
# (('went', 'so'), 1)
# (('went', 'they'), 1)
# (('went', 'to'), 1)
# (('went', 'the'), 1)
# (('to', 'they'), 1)
# (('to', 'went'), 1)
# (('to', 'the'), 1)
# (('to', 'store'), 1)
# (('the', 'went'), 1)
# (('the', 'to'), 1)
# (('the', 'store'), 1)
# (('the', 'and'), 1)
# (('store', 'to'), 1)
# (('store', 'the'), 1)
# (('store', 'and'), 1)
# (('store', 'bought'), 1)
# (('and', 'the'), 1)
# (('and', 'store'), 1)
# (('and', 'bought'), 1)
# (('and', 'a'), 1)
# (('bought', 'store'), 1)
# (('bought', 'and'), 1)
# (('bought', 'a'), 1)
# (('bought', 'new'), 1)
# (('a', 'and'), 1)
# (('a', 'bought'), 1)
# (('a', 'new'), 1)
# (('a', 'printer'), 1)
# (('new', 'bought'), 1)
# (('new', 'a'), 1)
# (('new', 'printer'), 1)
# (('new', 'they'), 1)
# (('printer', 'a'), 1)
# (('printer', 'new'), 1)
# (('printer', 'they'), 1)
# (('printer', 'printed'), 1)
# (('they', 'new'), 1)
# (('they', 'printer'), 1)
# (('they', 'printed'), 1)
# (('they', 'a'), 1)
# (('printed', 'printer'), 1)
# (('printed', 'they'), 1)
# (('printed', 'a'), 1)
# (('printed', 'new'), 1)
# (('a', 'they'), 1)
# (('a', 'printed'), 1)
# (('a', 'new'), 1)
# (('a', 'picture'), 1)
# (('new', 'printed'), 1)
# (('new', 'a'), 1)
# (('new', 'picture'), 1)
# (('new', 'of'), 1)
# (('picture', 'a'), 1)
# (('picture', 'new'), 1)
# (('picture', 'of'), 1)
# (('picture', 'the'), 1)
# (('of', 'new'), 1)
# (('of', 'picture'), 1)
# (('of', 'the'), 1)
# (('of', 'man'), 1)
# (('the', 'picture'), 1)
# (('the', 'of'), 1)
# (('the', 'man'), 1)
# (('the', 's'), 1)
# (('man', 'of'), 1)
# (('man', 'the'), 1)
# (('man', 's'), 1)
# (('man', 'wife'), 1)
# (('s', 'the'), 1)
# (('s', 'man'), 1)
# (('s', 'wife'), 1)
# (('s', 'and'), 1)
# (('wife', 'man'), 1)
# (('wife', 's'), 1)
# (('wife', 'and'), 1)
# (('wife', 'it'), 1)
# (('and', 's'), 1)
# (('and', 'wife'), 1)
# (('and', 'it'), 1)
# (('and', 'looked'), 1)
# (('it', 'wife'), 1)
# (('it', 'and'), 1)
# (('it', 'looked'), 1)
# (('it', 'beautiful'), 1)
# (('looked', 'and'), 1)
# (('looked', 'it'), 1)
# (('looked', 'beautiful'), 1)
# (('looked', 'the'), 1)
# (('beautiful', 'it'), 1)
# (('beautiful', 'looked'), 1)
# (('beautiful', 'the'), 1)
# (('beautiful', 'man'), 1)
# (('the', 'looked'), 1)
# (('the', 'beautiful'), 1)
# (('the', 'man'), 1)
# (('the', 'said'), 1)
# (('man', 'beautiful'), 1)
# (('man', 'the'), 1)
# (('man', 'said'), 1)
# (('man', 'thank'), 1)
# (('said', 'the'), 1)
# (('said', 'man'), 1)
# (('said', 'thank'), 1)
# (('said', 'you'), 1)
# (('thank', 'man'), 1)
# (('thank', 'said'), 1)
# (('thank', 'you'), 1)
# (('thank', 'for'), 1)
# (('you', 'said'), 1)
# (('you', 'thank'), 1)
# (('you', 'for'), 1)
# (('you', 'helping'), 1)
# (('for', 'thank'), 1)
# (('for', 'you'), 1)
# (('for', 'helping'), 1)
# (('for', 'me'), 1)
# (('helping', 'you'), 1)
# (('helping', 'for'), 1)
# (('helping', 'me'), 1)
# (('helping', 'son'), 1)
# (('me', 'for'), 1)
# (('me', 'helping'), 1)
# (('me', 'son'), 1)
# (('me', 'the'), 1)
# (('son', 'helping'), 1)
# (('son', 'me'), 1)
# (('son', 'the'), 1)
# (('son', 'son'), 1)
# (('the', 'me'), 1)
# (('the', 'son'), 1)
# (('the', 'son'), 1)
# (('the', 'replied'), 1)
# (('son', 'son'), 1)
# (('son', 'the'), 1)
# (('son', 'replied'), 1)
# (('son', 'you'), 1)
# (('replied', 'the'), 1)
# (('replied', 'son'), 1)
# (('replied', 'you'), 1)
# (('replied', 're'), 1)
# (('you', 'son'), 1)
# (('you', 'replied'), 1)
# (('you', 're'), 1)
# (('you', 'welcome'), 1)
# (('re', 'replied'), 1)
# (('re', 'you'), 1)
# (('re', 'welcome'), 1)
# (('re', 'daddy'), 1)
# (('welcome', 'you'), 1)
# (('welcome', 're'), 1)
# (('welcome', 'daddy'), 1)
# (('welcome', 'one'), 1)
# (('daddy', 're'), 1)
# (('daddy', 'welcome'), 1)
# (('daddy', 'one'), 1)
# (('daddy', 'day'), 1)
# (('one', 'welcome'), 1)
# (('one', 'daddy'), 1)
# (('one', 'day'), 1)
# (('one', 'a'), 1)
# (('day', 'daddy'), 1)
# (('day', 'one'), 1)
# (('day', 'a'), 1)
# (('day', 'boy'), 1)
# (('a', 'one'), 1)
# (('a', 'day'), 1)
# (('a', 'boy'), 1)
# (('a', 'named'), 1)
# (('boy', 'day'), 1)
# (('boy', 'a'), 1)
# (('boy', 'named'), 1)
# (('boy', 'tim'), 1)
# (('named', 'a'), 1)
# (('named', 'boy'), 1)
# (('named', 'tim'), 1)
# (('named', 'went'), 1)
# (('tim', 'boy'), 1)
# (('tim', 'named'), 1)
# (('tim', 'went'), 1)
# (('tim', 'to'), 1)
# (('went', 'named'), 1)
# (('went', 'tim'), 1)
# (('went', 'to'), 1)
# (('went', 'the'), 1)
# (('to', 'tim'), 1)
# (('to', 'went'), 1)
# (('to', 'the'), 1)
# (('to', 'river'), 1)
# (('the', 'went'), 1)
# (('the', 'to'), 1)
# (('the', 'river'), 1)
# (('the', 'with'), 1)
# (('river', 'to'), 1)
# (('river', 'the'), 1)
# (('river', 'with'), 1)
# (('river', 'his'), 1)
# (('with', 'the'), 1)
# (('with', 'river'), 1)
# (('with', 'his'), 1)
# (('with', 'dad'), 1)
# (('his', 'river'), 1)
# (('his', 'with'), 1)
# (('his', 'dad'), 1)
# (('his', 'they'), 1)
# (('dad', 'with'), 1)
# (('dad', 'his'), 1)
# (('dad', 'they'), 1)
# (('dad', 'wanted'), 1)
# (('they', 'his'), 1)
# (('they', 'dad'), 1)
# (('they', 'wanted'), 1)
# (('they', 'to'), 1)
# (('wanted', 'dad'), 1)
# (('wanted', 'they'), 1)
# (('wanted', 'to'), 1)
# (('wanted', 'catch'), 1)
# (('to', 'they'), 1)
# (('to', 'wanted'), 1)
# (('to', 'catch'), 1)
# (('to', 'some'), 1)
# (('catch', 'wanted'), 1)
# (('catch', 'to'), 1)
# (('catch', 'some'), 1)
# (('catch', 'fish'), 1)
# (('some', 'to'), 1)
# (('some', 'catch'), 1)
# (('some', 'fish'), 1)
# (('some', 'tim'), 1)
# (('fish', 'catch'), 1)
# (('fish', 'some'), 1)
# (('fish', 'tim'), 1)
# (('fish', 'felt'), 1)
# (('tim', 'some'), 1)
# (('tim', 'fish'), 1)
# (('tim', 'felt'), 1)
# (('tim', 'lucky'), 1)
# (('felt', 'fish'), 1)
# (('felt', 'tim'), 1)
# (('felt', 'lucky'), 1)
# (('felt', 'today'), 1)
# (('lucky', 'tim'), 1)
# (('lucky', 'felt'), 1)
# (('lucky', 'today'), 1)
# (('lucky', 'he'), 1)
# (('today', 'felt'), 1)
# (('today', 'lucky'), 1)
# (('today', 'he'), 1)
# (('today', 'thought'), 1)
# (('he', 'lucky'), 1)
# (('he', 'today'), 1)
# (('he', 'thought'), 1)
# (('he', 'he'), 1)
# (('thought', 'today'), 1)
# (('thought', 'he'), 1)
# (('thought', 'he'), 1)
# (('thought', 'would'), 1)
# (('he', 'he'), 1)
# (('he', 'thought'), 1)
# (('he', 'would'), 1)
# (('he', 'catch'), 1)
# (('would', 'thought'), 1)
# (('would', 'he'), 1)
# (('would', 'catch'), 1)
# (('would', 'a'), 1)
# (('catch', 'he'), 1)
# (('catch', 'would'), 1)
# (('catch', 'a'), 1)
# (('catch', 'big'), 1)
# (('a', 'would'), 1)
# (('a', 'catch'), 1)
# (('a', 'big'), 1)
# (('a', 'fish'), 1)
# (('big', 'catch'), 1)
# (('big', 'a'), 1)
# (('big', 'fish'), 1)
# (('big', 'tim'), 1)
# (('fish', 'a'), 1)
# (('fish', 'big'), 1)
# (('fish', 'tim'), 1)
# (('fish', 'and'), 1)
# (('tim', 'big'), 1)
# (('tim', 'fish'), 1)
# (('tim', 'and'), 1)
# (('tim', 'his'), 1)
# (('and', 'fish'), 1)
# (('and', 'tim'), 1)
# (('and', 'his'), 1)
# (('and', 'dad'), 1)
# (('his', 'tim'), 1)
# (('his', 'and'), 1)
# (('his', 'dad'), 1)
# (('his', 'put'), 1)
# (('dad', 'and'), 1)
# (('dad', 'his'), 1)
# (('dad', 'put'), 1)
# (('dad', 'their'), 1)
# (('put', 'his'), 1)
# (('put', 'dad'), 1)
# (('put', 'their'), 1)
# (('put', 'fishing'), 1)
# (('their', 'dad'), 1)
# (('their', 'put'), 1)
# (('their', 'fishing'), 1)
# (('their', 'rods'), 1)
# (('fishing', 'put'), 1)
# (('fishing', 'their'), 1)
# (('fishing', 'rods'), 1)
# (('fishing', 'in'), 1)
# (('rods', 'their'), 1)
# (('rods', 'fishing'), 1)
# (('rods', 'in'), 1)
# (('rods', 'the'), 1)
# (('in', 'fishing'), 1)
# (('in', 'rods'), 1)
# (('in', 'the'), 1)
# (('in', 'water'), 1)
# (('the', 'rods'), 1)
# (('the', 'in'), 1)
# (('the', 'water'), 1)
# (('the', 'they'), 1)
# (('water', 'in'), 1)
# (('water', 'the'), 1)
# (('water', 'they'), 1)
# (('water', 'waited'), 1)
# (('they', 'the'), 1)
# (('they', 'water'), 1)
# (('they', 'waited'), 1)
# (('they', 'for'), 1)
# (('waited', 'water'), 1)
# (('waited', 'they'), 1)
# (('waited', 'for'), 1)
# (('waited', 'a'), 1)
# (('for', 'they'), 1)
# (('for', 'waited'), 1)
# (('for', 'a'), 1)
# (('for', 'long'), 1)
# (('a', 'waited'), 1)
# (('a', 'for'), 1)
# (('a', 'long'), 1)
# (('a', 'time'), 1)
# (('long', 'for'), 1)
# (('long', 'a'), 1)
# (('long', 'time'), 1)
# (('long', 'suddenly'), 1)
# (('time', 'a'), 1)
# (('time', 'long'), 1)
# (('time', 'suddenly'), 1)
# (('time', 'tim'), 1)
# (('suddenly', 'long'), 1)
# (('suddenly', 'time'), 1)
# (('suddenly', 'tim'), 1)
# (('suddenly', 'felt'), 1)
# (('tim', 'time'), 1)
# (('tim', 'suddenly'), 1)
# (('tim', 'felt'), 1)
# (('tim', 'something'), 1)
# (('felt', 'suddenly'), 1)
# (('felt', 'tim'), 1)
# (('felt', 'something'), 1)
# (('felt', 'pull'), 1)
# (('something', 'tim'), 1)
# (('something', 'felt'), 1)
# (('something', 'pull'), 1)
# (('something', 'on'), 1)
# (('pull', 'felt'), 1)
# (('pull', 'something'), 1)
# (('pull', 'on'), 1)
# (('pull', 'his'), 1)
# (('on', 'something'), 1)
# (('on', 'pull'), 1)
# (('on', 'his'), 1)
# (('on', 'rod'), 1)
# (('his', 'pull'), 1)
# (('his', 'on'), 1)
# (('his', 'rod'), 1)
# (('his', 'dad'), 1)
# (('rod', 'on'), 1)
# (('rod', 'his'), 1)
# (('rod', 'dad'), 1)
# (('rod', 'i'), 1)
# (('dad', 'his'), 1)
# (('dad', 'rod'), 1)
# (('dad', 'i'), 1)
# (('dad', 'got'), 1)
# (('i', 'rod'), 1)
# (('i', 'dad'), 1)
# (('i', 'got'), 1)
# (('i', 'a'), 1)
# (('got', 'dad'), 1)
# (('got', 'i'), 1)
# (('got', 'a'), 1)
# (('got', 'fish'), 1)
# (('a', 'i'), 1)
# (('a', 'got'), 1)
# (('a', 'fish'), 1)
# (('a', 'tim'), 1)
# (('fish', 'got'), 1)
# (('fish', 'a'), 1)
# (('fish', 'tim'), 1)
# (('fish', 'said'), 1)
# (('tim', 'a'), 1)
# (('tim', 'fish'), 1)
# (('tim', 'said'), 1)
# (('tim', 'his'), 1)
# (('said', 'fish'), 1)
# (('said', 'tim'), 1)
# (('said', 'his'), 1)
# (('said', 'dad'), 1)
# (('his', 'tim'), 1)
# (('his', 'said'), 1)
# (('his', 'dad'), 1)
# (('his', 'helped'), 1)
# (('dad', 'said'), 1)
# (('dad', 'his'), 1)
# (('dad', 'helped'), 1)
# (('dad', 'him'), 1)
# (('helped', 'his'), 1)
# (('helped', 'dad'), 1)
# (('helped', 'him'), 1)
# (('helped', 'pull'), 1)
# (('him', 'dad'), 1)
# (('him', 'helped'), 1)
# (('him', 'pull'), 1)
# (('him', 'the'), 1)
# (('pull', 'helped'), 1)
# (('pull', 'him'), 1)
# (('pull', 'the'), 1)
# (('pull', 'fish'), 1)
# (('the', 'him'), 1)
# (('the', 'pull'), 1)
# (('the', 'fish'), 1)
# (('the', 'out'), 1)
# (('fish', 'pull'), 1)
# (('fish', 'the'), 1)
# (('fish', 'out'), 1)
# (('fish', 'of'), 1)
# (('out', 'the'), 1)
# (('out', 'fish'), 1)
# (('out', 'of'), 1)
# (('out', 'the'), 1)
# (('of', 'fish'), 1)
# (('of', 'out'), 1)
# (('of', 'the'), 1)
# (('of', 'water'), 1)
# (('the', 'out'), 1)
# (('the', 'of'), 1)
# (('the', 'water'), 1)
# (('the', 'the'), 1)
# (('water', 'of'), 1)
# (('water', 'the'), 1)
# (('water', 'the'), 1)
# (('water', 'fish'), 1)
# (('the', 'the'), 1)
# (('the', 'water'), 1)
# (('the', 'fish'), 1)
# (('the', 'was'), 1)
# (('fish', 'water'), 1)
# (('fish', 'the'), 1)
# (('fish', 'was'), 1)
# (('fish', 'big'), 1)
# (('was', 'the'), 1)
# (('was', 'fish'), 1)
# (('was', 'big'), 1)
# (('was', 'and'), 1)
# (('big', 'fish'), 1)
# (('big', 'was'), 1)
# (('big', 'and'), 1)
# (('big', 'shiny'), 1)
# (('and', 'was'), 1)
# (('and', 'big'), 1)
# (('and', 'shiny'), 1)
# (('and', 'tim'), 1)
# (('shiny', 'big'), 1)
# (('shiny', 'and'), 1)
# (('shiny', 'tim'), 1)
# (('shiny', 'was'), 1)
# (('tim', 'and'), 1)
# (('tim', 'shiny'), 1)
# (('tim', 'was'), 1)
# (('tim', 'v'), 1)
# (('was', 'shiny'), 1)
# (('was', 'tim'), 1)
# (('was', 'v'), 1)
# (('v', 'tim'), 1)
# (('v', 'was'), 1)

# %% [markdown]
# ##Model training

# %%
from tensorflow.keras.layers import Dot, Dense, Embedding, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K


# Parameters
embedding_dim = 100
window_size = 2
num_neg_samples = 5
vocab_size = len(vocabulary)

# Generate training data
def generate_training_data(labeled_data, word_to_index, window_size, num_neg_samples):
    for data in labeled_data:
        target_word, context_word = data[0]
        label = data[1]
        context_index = word_to_index[context_word]
        target_index = word_to_index[target_word]
        yield (context_index, target_index, label)
        for _ in range(num_neg_samples):
            neg_word = np.random.choice(list(vocabulary))
            while neg_word == context_word:
                neg_word = np.random.choice(list(vocabulary))
            neg_index = word_to_index[neg_word]
            yield (context_index, neg_index, 0)

# Define the Skip-Gram with Negative Sampling (SGNS) model
input_target = Input((1,))
input_context = Input((1,))

embedding = Embedding(vocab_size, embedding_dim, input_length=1, name='embedding')

target = embedding(input_target)
context = embedding(input_context)

dot_product = Dot(axes=2, normalize=False)([target, context])
dot_product = Dense(1, activation='sigmoid')(dot_product)

model = Model(inputs=[input_target, input_context], outputs=dot_product)

# Define the custom loss function based on the negative sampling objective
def sgns_loss(y_true, y_pred):
    return K.mean(tf.math.log1p(y_pred) + K.mean(tf.math.log1p(1 - y_pred), axis=-1), axis=-1)

# Compile the model with the custom loss function
model.compile(loss=sgns_loss, optimizer='adam')

# Generate training data
training_data = list(generate_training_data(labeled_data, word_to_index, window_size, num_neg_samples))

# Extract the data for training
target_data = np.array([data[0] for data in training_data], dtype="int32")
context_data = np.array([data[1] for data in training_data], dtype="int32")
label_data = np.array([data[2] for data in training_data], dtype="float32")

# Reshape the data
#target_data = np.reshape(target_data, (-1, 1))
#context_data = np.reshape(context_data, (-1, 1))
#label_data = np.reshape(label_data, (-1, 1))

# Train the model
model.fit([target_data, context_data], label_data, batch_size=64, epochs=8)
# Out:
# Epoch 1/8
# 3763/3763 [==============================] - 18s 5ms/step - loss: 0.7221
# Epoch 2/8
# 3763/3763 [==============================] - 15s 4ms/step - loss: 0.6931
# Epoch 3/8
# 3763/3763 [==============================] - 15s 4ms/step - loss: 0.6931
# Epoch 4/8
# 3763/3763 [==============================] - 15s 4ms/step - loss: 0.6931
# Epoch 5/8
# 3763/3763 [==============================] - 15s 4ms/step - loss: 0.6931
# Epoch 6/8
# 3763/3763 [==============================] - 15s 4ms/step - loss: 0.6931
# Epoch 7/8
# 3763/3763 [==============================] - 14s 4ms/step - loss: 0.6931
# Epoch 8/8
# 3763/3763 [==============================] - 15s 4ms/step - loss: 0.6931

# %%
# Evaluate the trained model
evaluation = model.evaluate([target_data, context_data], label_data)
# Out:
# 75139/75139 [==============================] - 135s 2ms/step - loss: 0.6926

# %%
evaluation
# Out:
# 0.6931766271591187

# %% [markdown]
# ##Hyper parameter tuning

# %%
pip install keras==2.12.0
# Out:
# Collecting keras==2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.2 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.14.0 requires keras<2.15,>=2.14.0, but you have keras 2.12.0 which is incompatible.
# Successfully installed keras-2.12.0

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Dot, Input
from tensorflow.keras.models import Model
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam

# Define the function to create the model
def create_model(embedding_dim, learning_rate):
    # Define the model architecture here
    input_target = Input((1,))
    input_context = Input((1,))

    embedding = Embedding(vocab_size, embedding_dim, input_length=1)

    target = embedding(input_target)
    context = embedding(input_context)

    dot_product = Dot(axes=2, normalize=False)([target, context])
    dot_product = Dense(1, activation='sigmoid')(dot_product)

    model = Model(inputs=[input_target, input_context], outputs=dot_product)
    model.compile(loss=sgns_loss, optimizer=Adam(learning_rate=learning_rate))
    return model

# Wrap the Keras model
keras_model = KerasClassifier(build_fn=create_model, epochs=5, batch_size=64, verbose=0)

# Define the hyperparameters to tune
param_grid = {
    'embedding_dim': [50, 100, 200],
    'learning_rate': [0.001, 0.01, 0.1]
}

# Convert data to numpy arrays if necessary
target_data_np = np.array(target_data)
context_data_np = np.array(context_data)
label_data_np = np.array(label_data)
# Perform grid search
grid = GridSearchCV(estimator=keras_model, param_grid=param_grid, cv=3)
print(len(target_data))
print(len(context_data))
print(len(label_data))
grid_result = grid.fit([target_data, context_data], label_data)

# Summarize results
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
means = grid_result.cv_results_['mean_test_score']
params = grid_result.cv_results_['params']
for mean, param in zip(means, params):
    print(f"Mean: {mean}, Params: {param}")
# Out:
# 240804
# 240804
# 240804
# <ipython-input-39-d5ea79423bf6>:28: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=create_model, epochs=5, batch_size=64, verbose=0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-d5ea79423bf6> in <cell line: 45>()
#      43 print(len(context_data))
#      44 print(len(label_data))
# ---> 45 grid_result = grid.fit([target_data, context_data], label_data)
#      46
#      47 # Summarize results
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     780             refit_metric = self.refit
#     781
# --> 782         X, y, groups = indexable(X, y, groups)
#     783         fit_params = _check_fit_params(X, fit_params)
#     784
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [2, 240804]

# %% [markdown]
# ###As I am facing some issues with keras fit method in GridsearchCV,I tuned the by rerunning it with different values of parameters and finally used best one.

# %% [markdown]
# ## Model testing

# %%
#reading 2nd datset for testing
file= open("interview_ds_2.txt", "r")
test = file.read()
#test=test[:500000]

# %%
test
# Out:
# '\nTina and her mom were walking down the street one day when suddenly the ground started to shake. Tina was scared and her mom was scared too. They both knew what it was: an earthquake!\nTina\'s mom held tightly onto her hand and said, "Let\'s hurry home, honey. Don\'t be scared." But it was hard to walk because the ground was shaking so much. Shoulders hunched, they struggled to make their way home.\nWhen they got there, Tina\'s mom tightly hugged her, saying, "We made it, sweetie! Now let\'s sit here and wait until it\'s over."\nTina was impatient and asked, "When will it end, mommy?"\nHer mom replied, "I\'m not sure, honey. We just have to wait and see."\nSo they sat quietly and held each other until the trembling stopped. Then they smiled and hugged each other, feeling glad that the struggle was over.Once upon a time, there was a small boy named Timmy. Timmy loved to eat oatmeal for breakfast every day. One day, Timmy\'s mom asked him if he wanted to help her make oatmeal. Timmy was excited and said yes.\nTimmy\'s mom showed him how to pour the oats into the pot and add water. Timmy stirred the oatmeal and waited for it to cook. When it was ready, Timmy\'s mom helped him pour it into a small bowl. Timmy was proud of himself for helping and he succeeded in making a delicious breakfast with his mom.One day, a little girl named Sue was playing with her toys. She saw her mom struggle to open the window. It was a hot day, and they needed some fresh air. Sue watched as her mom tried and tried to open the window, but it was stuck. Sue wanted to help, but she was too small. She thought maybe, one day, she could be big and strong like her mom.\nLater, Sue was watching her favorite show on the screen. The screen started to get hot. She remembered how her mom had struggled with the window. Sue thought, "I can try to open the window too!" She stood up and walked to the window.\nSue tried to open the window, just like her mom. She struggled a little bit, but then, the window opened! Fresh air came in, and the screen was not hot anymore. Sue was so happy! She felt big and strong, just like her mom.Once upon a time, there was a little boy named Tim. Tim lived on a small planet with his family. They had a big garden with lots of yummy fruits and vegetables. Tim loved to eat the yummy fruits every day.\nOne day, Tim saw a big box in the garden. It had a lock on it. Tim was very curious and wanted to open the box. He asked his mom and dad for the key, but they said no. They told him that the box was not for him.\nTim was sad, but he listened to his mom and dad. He did not try to open the box. He went back to eating the yummy fruits in the garden. Soon, he forgot about the box with the lock.\nOne day, a wise old man came to visit Tim\'s family. The old man saw the box with the lock and asked Tim if he knew what was inside. Tim said no, but he told the old man that he listened to his mom and dad and did not try to open it.\nThe wise old man smiled and said, "Good job, Tim! You have learned the important lesson of listening to your parents. They know what is best for you." Tim was happy that he had made the right choice. He knew that listening to his mom and dad was always the best thing to do.Once upon a time, there was a big castle with a lot of staff. The staff were all very busy, running around and cleaning things. One day, a little girl came to the castle. She wanted to see the big king who lived there. But the staff said she couldn\'t see him. \nThe little girl was sad and sat down on the ground. Suddenly, she saw a big dragon coming towards the castle. The staff were all scared and didn\'t know what to do. But the little girl was brave. She stood up and told the dragon to sit down. And to everyone\'s surprise, the dragon listened! \nThe little girl became a hero and the staff were so happy. They let her see the king and he was very impressed with her bravery. From that day on, the little girl was always welcome at the castle and the st ...

# %% [markdown]
# ##Data preprocessing

# %%
import re
# Tokenization
words = re.findall(r'\b\w+\b', test)

# Convert to lowercase
words = [word.lower() for word in words]

# Build Vocabulary
vocabulary = set(words)
word_to_index = {word: i for i, word in enumerate(vocabulary)}
index_to_word = {i: word for i, word in enumerate(vocabulary)}

# Generate Word Pairs
window_size = 2
word_pairs = []
for i, word in enumerate(words):
    for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
        if i != j:
            context_word = words[j]
            word_pairs.append((word, context_word))

# Assign Labels
test_labeled_data = [(pair, 1) for pair in word_pairs]

# %% [markdown]
# ##Model testing

# %%
# Generate test data
test_data = list(generate_training_data(test_labeled_data, word_to_index, window_size, num_neg_samples))

# Extract the data for testing
test_target_data = np.array([data[0] for data in test_data], dtype="int32")
test_context_data = np.array([data[1] for data in test_data], dtype="int32")
test_label_data = np.array([data[2] for data in test_data], dtype="float32")

# Evaluate the model on test data
test_loss = model.evaluate([test_target_data, test_context_data], test_label_data)

print("Test loss:", test_loss)
# Out:
# 747/747 [==============================] - 2s 2ms/step - loss: 0.6933
# Test loss: 0.6932780146598816
